# %% [markdown]
# # Pandas
# ## Loading data
# We'll start by looking at loading data in Pandas. First we'll load a simple CSV file. The file looks like this:
#
# ```
# sales_USD,year,genre
# 1561.2300000000005,2009,Rock
# 185.13,2009,Jazz
# 502.92000000000013,2009,Metal
# 466.29000000000025,2009,Alternative & Punk
# ```

# %% [markdown]
# We can load the data and look at the top and bottom of the file with `head` and `tail`:

# %%
import pandas as pd
df = pd.read_csv('data/chinook_data.csv')
df.head()
# Out:
#    sales_USD  year               genre
# 0    1561.23  2009                Rock
# 1     185.13  2009                Jazz
# 2     502.92  2009               Metal
# 3     466.29  2009  Alternative & Punk
# 4      13.86  2009       Rock And Roll

# %%
df.tail()
# Out:
#      sales_USD  year            genre
# 99       41.58  2013            World
# 100       6.93  2013      Hip Hop/Rap
# 101      25.86  2013  Science Fiction
# 102     157.15  2013         TV Shows
# 103     129.30  2013            Drama

# %% [markdown]
# Two of the fundamental data structures in pandas are Series and DataFrames. A series is 1D, while a DataFrame is 2D.

# %%
df['year']
# Out:
# 0      2009
# 1      2009
# 2      2009
# 3      2009
# 4      2009
#        ...
# 99     2013
# 100    2013
# 101    2013
# 102    2013
# 103    2013
# Name: year, Length: 104, dtype: int64

# %%
type(df['year'])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# The documentation for [`read_csv`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html) has a lot of options, all described well in the docs. One useful option combination is for parsing dates:

# %%
df = pd.read_csv('data/chinook_data.csv', parse_dates=['year'], infer_datetime_format=True)
df.head()
# Out:
#    sales_USD       year               genre
# 0    1561.23 2009-01-01                Rock
# 1     185.13 2009-01-01                Jazz
# 2     502.92 2009-01-01               Metal
# 3     466.29 2009-01-01  Alternative & Punk
# 4      13.86 2009-01-01       Rock And Roll

# %% [markdown]
# The column on the left is the index. Since we did not specify an index column when loading the data, it was generated for us.

# %%
df.index
# Out:
# RangeIndex(start=0, stop=104, step=1)

# %% [markdown]
# Write back to CSV with new date format. Since the index was automatically created, we will not write it to the file with `index=False`.

# %%
df.to_csv('data/chinook_data_2.csv', index=False)

# %% [markdown]
# You could now try loading the file again, or looking at it in a text editor or Excel or OpenOffice.
#
# Sometimes we have other separators in our CSV files, like a tab character (`\t`) or a pipe (`|`). We can specify the separator with `read_csv`:

# %%
df = pd.read_csv('data/chinook_data.tsv', sep='\t')
df.head()
# Out:
#    sales_USD  year               genre
# 0    1561.23  2009                Rock
# 1     185.13  2009                Jazz
# 2     502.92  2009               Metal
# 3     466.29  2009  Alternative & Punk
# 4      13.86  2009       Rock And Roll

# %% [markdown]
# We can also leave the `sep` argument as `None`, and Python auto-detects it:

# %%
df = pd.read_csv('data/chinook_data.tsv', sep=None)
df.head()
# Out:
# <ipython-input-8-536f0a238cf2>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support sep=None with delim_whitespace=False; you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv('data/chinook_data.tsv', sep=None)
#    sales_USD  year               genre
# 0    1561.23  2009                Rock
# 1     185.13  2009                Jazz
# 2     502.92  2009               Metal
# 3     466.29  2009  Alternative & Punk
# 4      13.86  2009       Rock And Roll

# %% [markdown]
# We can also read CSV from a URL. For example, we can load the CSV from the GitHub URL.

# %%
url = 'https://raw.githubusercontent.com/PacktPublishing/Practical-Data-Science-with-Python/main/Chapter4/chinook_data.csv'
df = pd.read_csv(url)
df.head()
# Out:
#    sales_USD  year               genre
# 0    1561.23  2009                Rock
# 1     185.13  2009                Jazz
# 2     502.92  2009               Metal
# 3     466.29  2009  Alternative & Punk
# 4      13.86  2009       Rock And Roll

# %% [markdown]
# Many files are stored in Excel format. Pandas comes with `read_excel` to handle those.

# %%
df = pd.read_excel('data/chinook_data.xlsx', sheet_name='sales_data', parse_dates=['year'])
df.head()
# Out:
#    sales_USD       year               genre
# 0    1561.23 2009-01-01                Rock
# 1     185.13 2009-01-01                Jazz
# 2     502.92 2009-01-01               Metal
# 3     466.29 2009-01-01  Alternative & Punk
# 4      13.86 2009-01-01       Rock And Roll

# %% [markdown]
# Similarly to CSVs, we can write Excel files with the same paradigm:

# %%
df.to_excel('data/chinook_data_2.xlsx', index=False)

# %% [markdown]
# Pandas can be used to interface with SQL databases as well. Here, we collect data from the chinook.db SQLite file from Chapter 3. We must first make a connection to the database; here we use SQLAlchemy but we could also use a `sqlite3` connection.

# %% [markdown]
# ### Write and read HDF

# %%
df.to_hdf('data/chinook_data.hdf', key='chinook_sales', mode='a', complevel=3)

# %%
df.to_hdf('data/chinook_data.hdf', key='chinook_sales2', mode='a', complevel=3)

# %%
df2 = pd.read_hdf('data/chinook_data.hdf', key='chinook_sales')
df2.head()
# Out:
#    sales_USD       year               genre
# 0    1561.23 2009-01-01                Rock
# 1     185.13 2009-01-01                Jazz
# 2     502.92 2009-01-01               Metal
# 3     466.29 2009-01-01  Alternative & Punk
# 4      13.86 2009-01-01       Rock And Roll

# %%
df3 = pd.read_hdf('data/chinook_data.hdf', key='chinook_sales2', start=-10)
df3.head()
# Out:
#     sales_USD       year              genre
# 94      23.76 2013-01-01         Bossa Nova
# 95      27.72 2013-01-01     Easy Listening
# 96      27.72 2013-01-01        Heavy Metal
# 97      48.51 2013-01-01           R&B/Soul
# 98      13.86 2013-01-01  Electronica/Dance

# %%
df3.shape
# Out:
# (10, 3)

# %% [markdown]
# ### Write and read feather.
# Feather format is good for reading/writing to and from R and Python (sharing data between the two), but is not good for storing data long-term since the format could change.
#
# You may get the error `ImportError: Missing optional dependency 'pyarrow'.  Use pip or conda to install pyarrow.`; if so, install with `conda install -c conda-forge pyarrow -y`.

# %%
df.to_feather('data/chinook_data.ft')
df4 = pd.read_feather('data/chinook_data.ft')
df4.head()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-19-b20942acf8e5> in <module>
# ----> 1 df.to_feather('data/chinook_data.ft')
#       2 df4 = pd.read_feather('data/chinook_data.ft')
#       3 df4.head()
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in to_feather(self, path, **kwargs)
#    2213         from pandas.io.feather_format import to_feather
#    2214
# -> 2215         to_feather(self, path, **kwargs)
#    2216
#    2217     @doc(
#
# ~\anaconda3\lib\site-packages\pandas\io\feather_format.py in to_feather(df, path, **kwargs)
#      21         .. versionadded:: 1.1.0
#      22     """
# ---> 23     import_optional_dependency("pyarrow")
#      24     from pyarrow import feather
#      25
#
# ~\anaconda3\lib\site-packages\pandas\compat\_optional.py in import_optional_dependency(name, extra, raise_on_missing, on_version)
#     108     except ImportError:
#     109         if raise_on_missing:
# --> 110             raise ImportError(msg) from None
#     111         else:
#     112             return None
#
# ImportError: Missing optional dependency 'pyarrow'.  Use pip or conda to install pyarrow.

# %% [markdown]
# ## Load data from SQL
# First, we create a connection with SQLalchemy, then load data into a DataFrame.  `read_sql_table` reads an entire table; to limit results or join tables, we can instead us `read_sql_query` with a query string (like in chapter 3).

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite:///data/chinook.db')
connection = engine.connect()

# %%
df = pd.read_sql_table('tracks', connection)
df.head()
# Out:
#    TrackId                                     Name  AlbumId  MediaTypeId  \
# 0        1  For Those About To Rock (We Salute You)        1            1
# 1        2                        Balls to the Wall        2            2
# 2        3                          Fast As a Shark        3            2
# 3        4                        Restless and Wild        3            2
# 4        5                     Princess of the Dawn        3            2
#
#    GenreId                                           Composer  Milliseconds  \
# 0        1          Angus Young, Malcolm Young, Brian Johnson        343719
# 1        1                                               None        342562
# 2        1  F. Baltes, S. Kaufman, U. Dirkscneider & W. Ho...        230619
# 3        1  F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. D...        252051
# 4        1                         Deaffy & R.A. Smith-Diesel        375418
#
#       Bytes  UnitPrice
# 0  11170334       0.99
# 1   5510424       0.99
# 2   3990994       0.99
# 3   4331779       0.99
# 4   6290521       0.99

# %% [markdown]
# ### Create DataFrame from Python lists.
# We will use the bitcoin data from "test your knowledge" from chapter 3 -- the high prices for each year from 2013 to 2020.

# %%
btc_data = [(1138.5, '2013'),
 (919.24, '2014'),
 (466.01, '2015'),
 (981.7, '2016'),
 (19210.0, '2017'),
 (17169.0, '2018'),
 (12876.0, '2019'),
 (19131.0, '2020')]

# %% [markdown]
# We can create a DataFrame directly from a list of data like we have:

# %%
df = pd.DataFrame(data=btc_data, columns=['high_price', 'year'])

# %%
df.head()
# Out:
#    high_price  year
# 0     1138.50  2013
# 1      919.24  2014
# 2      466.01  2015
# 3      981.70  2016
# 4    19210.00  2017

# %% [markdown]
# We can also create a DataFrame from lists. First we need to get the two lists out of our data.

# %%
high_price = [b[0] for b in btc_data]
year = [b[1] for b in btc_data]

# %%
df = pd.DataFrame(data={'high_price': high_price, 'year': year})
df.head()
# Out:
#    high_price  year
# 0     1138.50  2013
# 1      919.24  2014
# 2      466.01  2015
# 3      981.70  2016
# 4    19210.00  2017

# %% [markdown]
# ### Convert JSON into a DataFrame.
# We sometimes encounter JSON data when downloading data from a website or API. For a .json file, we can simply load it with `read_json`:

# %%
df = pd.read_json('data/bitcoin_price.json')
df.head()
# Out:
#    symbol           time        open       close       high        low  \
# 0  btcusd  1364688000000   92.500000   93.033000   93.74999   91.00000
# 1  btcusd  1364774400000   93.250000  103.999000  105.90000   92.49999
# 2  btcusd  1364860800000  104.000000  118.229354  118.38670   99.00000
# 3  btcusd  1364947200000  117.958261  134.700000  146.88000  101.51088
# 4  btcusd  1365033600000  134.716560  132.899000  143.00000  119.00000
#
#          volume
# 0   3083.079791
# 1   5224.401313
# 2   8376.527478
# 3  12996.245072
# 4   6981.668305

# %%
# write to csv to test out chunksize later
df.to_csv('data/bitcoin_price.csv', index=False)

# %% [markdown]
# We can also take JSON data and parse it into a pandas DataFrame:

# %%
import json

# %%
with open('data/bitcoin_price.json') as f:
    json_data = json.load(f)

# %%
json_data
# Out:
# [{'symbol': 'btcusd',
#   'time': 1364688000000,
#   'open': 92.5,
#   'close': 93.033,
#   'high': 93.74999,
#   'low': 91.0,
#   'volume': 3083.07979075},
#  {'symbol': 'btcusd',
#   'time': 1364774400000,
#   'open': 93.25,
#   'close': 103.999,
#   'high': 105.9,
#   'low': 92.49999,
#   'volume': 5224.40131297},
#  {'symbol': 'btcusd',
#   'time': 1364860800000,
#   'open': 104.0,
#   'close': 118.22935407,
#   'high': 118.3867,
#   'low': 99.0,
#   'volume': 8376.52747811002},
#  {'symbol': 'btcusd',
#   'time': 1364947200000,
#   'open': 117.95826131,
#   'close': 134.7,
#   'high': 146.88,
#   'low': 101.51088,
#   'volume': 12996.2450721801},
#  {'symbol': 'btcusd',
#   'time': 1365033600000,
#   'open': 134.71656,
#   'close': 132.899,
#   'high': 143.0,
#   'low': 119.0,
#   'volume': 6981.66830544001},
#  {'symbol': 'btcusd',
#   'time': 1365120000000,
#   'open': 130.10001,
#   'close': 142.3,
#   'high': 145.0,
#   'low': 128.25,
#   'volume': 5234.88220325001},
#  {'symbol': 'btcusd',
#   'time': 1365206400000,
#   'open': 142.8,
#   'close': 143.05,
#   'high': 144.0,
#   'low': 139.0,
#   'volume': 2009.12862494},
#  {'symbol': 'btcusd',
#   'time': 1365292800000,
#   'open': 143.5,
#   'close': 162.304,
#   'high': 164.75,
#   'low': 142.75,
#   'volume': 3725.06764496},
#  {'symbol': 'btcusd',
#   'time': 1365379200000,
#   'open': 163.9,
#   'close': 186.985,
#   'high': 194.57,
#   'low': 163.2,
#   'volume': 10895.82741442},
#  {'symbol': 'btcusd',
#   'time': 1365465600000,
#   'open': 186.8,
#   'close': 232.99,
#   'high': 249.97,
#   'low': 186.8,
#   'volume': 6073.37314608},
#  {'symbol': 'btcusd',
#   'time': 1365552000000,
#   'open': 228.669,
#   'close': 162.0,
#   'high': 290.0,
#   'low': 19.9,
#   'volume': 16070.6427442701},
#  {'symbol': 'btcusd',
#   'time': 1365638400000,
#   'open': 162.0,
#   'close': 100.0,
#   'high': 205.0,
#   'low': 1.06,
#   'volume': 16914.6563150801},
#  {'symbol': 'btcusd',
#   'time': 1365724800000,
#   'open': 109.0,
#   'close': 112.0,
#   'high': 157.0,
#   'low': 51.0,
#   'volume': 38693.9553043196},
#  {'symbol': 'btcusd',
#   'time': 1365811200000,
#   'open': 112.0,
#   'close': 91.1,
#   'high': 130.0,
#   'low': 81.12,
#   'volume': 23866.6770456},
#  {'symbol': 'btcusd',
#   'time': 1365897600000,
#   'open': 91.1,
#   'close': 90.171,
#   'high': 109.0,
#   'low': 20.0,
#   'volume': 16437.2196645},
#  {'symbol': 'btcusd',
#   'time': 1365984000000,
#   'open': 89.86,
#   'close': 83.302,
#   'high': 104.0,
#   'low': 71.497,
#   'volume': 16393.12856398},
#  {'symbol': 'btcusd',
#   'time': 1366070400000,
#   'open': 84.27,
#   'close': 67.588,
#   'high': 84.48,
#   'low': 0.01,
#   'volume': 26092.5432296},
#  {'symbol': 'btcusd',
#   'time': 1366156800000,
#   'open': 68.135,
#   'close': 93.063,
#   'high': 98.9,
#   'low': 63.5,
#   'volume': 20016.46738673},
#  {'symbol': 'btcusd',
#   'time': 1366243200000,
#   'open': 93.0,
#   'close': 111.3,
#   'high': 114.0,
#   'low': 87.0,
#   'volume': 8362.10465509001},
#  {'symbol': 'btcusd',
#   'time': 1366329600000,
#   'open': 110.0,
#   'close': 119.0,
#   'high': 142.0,
#   'low': 104.56,
#   'volume': 20883.2511054899},
#  {'symbol': 'btcusd',
#   'time': 1366416000000,
#   'open': 119.02,
#   'close': 127.0,
#   'high': 132.0,
#   'low': 114.9,
#   'volume': 6502.71927697004},
#  {'symbol': 'btcusd',
#   'time': 1366502400000,
#   'open': 127.01,
#   'close': 117.618,
#   'high': 130.0,
#   'low': 110.0,
#   'volume': 11539.05619005},
#  {'symbol': 'btcusd',
#   'time': 1366588800000,
#   'open': 119.96,
#   'close': 126.5,
#   'high': 127.3,
#   'low': 119.615,
#   'volume': 7053.39711668},
#  {'symbol': 'btcusd',
#   'time': 1366675200000,
#   'open': 127.389,
#   'close': 143.484,
#   'high': 144.47,
#   'low': 124.859,
#   'volume': 11566.57797156},
#  {'symbol': 'btcusd',
#   'time': 1366761600000,
#   'open': 142.41,
#   'close': 154.6,
#   'high': 166.99,
#   'low': 140.9,
#   'volume': 25884.62525415},
#  {'symbol': 'btcusd',
#   'time': 1366848000000,
#   'open': 155.0,
#   'close': 141.9,
#   'high': 169.13,
#   'low': 120.03,
#   'volume': 21589.72100785},
#  {'symbol': 'btcusd',
#   'time': 1366934400000,
#   'open': 142.89,
#   'close': 137.3,
#   'high': 143.985,
#   'low': 13.0,
#   'volume': 13279.17946705},
#  {'symbol': 'btcusd',
#   'time': 1367020800000,
#   'open': 136.56001,
#   'close': 128.5,
#   'high': 147.51,
#   'low': 121.46,
#   'volume': 7773.99732283001},
#  {'symbol': 'btcusd',
#   'time': 1367107200000,
#   'open': 128.8,
#   'close': 135.28,
#   'high': 136.99,
#   'low': 128.02,
#   'volume': 7222.09008288002},
#  {'symbol': 'btcusd',
#   'time': 1367193600000,
#   'open': 134.63,
#   'close': 144.0,
#   'high': 148.5,
#   'low': 113.42,
#   'volume': 9491.69208741002},
#  {'symbol': 'btcusd',
#   'time': 1367280000000,
#   'open': 143.89,
#   'close': 139.88,
#   'high': 146.6752,
#   'low': 133.89,
#   'volume': 10916.4540109801},
#  {'symbol': 'btcusd',
#   'time': 1367366400000,
#   'open': 139.87,
#   'close': 116.0,
#   'high': 140.02,
#   'low': 105.0,
#   'volume': 23869.0625977401},
#  {'symbol': 'btcusd',
#   'time': 1367452800000,
#   'open': 116.75,
#   'close': 106.6,
#   'high': 127.18,
#   'low': 90.414,
#   'volume': 29911.7420357899},
#  {'symbol': 'btcusd',
#   'time': 1367539200000,
#   'open': 107.0,
#   'close': 98.06,
#   'high': 108.21,
#   'low': 80.0,
#   'volume': 32551.0515293098},
#  {'symbol': 'btcusd',
#   'time': 1367625600000,
#   'open': 98.5,
#   'close': 112.5,
#   'high': 115.959,
#   'low': 93.356,
#   'volume': 15470.5403185301},
#  {'symbol': 'btcusd',
#   'time': 1367712000000,
#   'open': 112.3,
#   'close': 116.57,
#   'high': 126.0,
#   'low': 100.0,
#   'volume': 13363.7807084401},
#  {'symbol': 'btcusd',
#   'time': 1367798400000,
#   'open': 116.587,
#   'close': 112.0,
#   'high': 124.3,
#   'low': 106.0,
#   'volume': 12263.0308212001},
#  {'symbol': 'btcusd',
#   'time': 1367884800000,
#   'open': 112.1,
#   'close': 110.0,
#   'high': 113.44,
#   'low': 98.0,
#   'volume': 15053.73044354},
#  {'symbol': 'btcusd',
#   'time': 1367971200000,
#   'open': 109.76,
#   'close': 113.5,
#   'high': 116.98,
#   'low': 108.5,
#   'volume': 8804.37823946003},
#  {'symbol': 'btcusd',
#   'time': 1368057600000,
#   'open': 113.495,
#   'close': 112.669,
#   'high': 113.5,
#   'low': 108.23,
#   'volume': 3991.56786689},
#  {'symbol': 'btcusd',
#   'time': 1368144000000,
#   'open': 112.653,
#   'close': 117.87,
#   'high': 122.5,
#   'low': 111.4,
#   'volume': 7579.66383688002},
#  {'symbol': 'btcusd',
#   'time': 1368230400000,
#   'open': 117.92,
#   'close': 115.576,
#   'high': 118.9,
#   'low': 112.72,
#   'volume': 3841.93708681},
#  {'symbol': 'btcusd',
#   'time': 1368316800000,
#   'open': 115.58,
#   'close': 114.3,
#   'high': 118.0,
#   'low': 113.0,
#   'volume': 2745.73340774},
#  {'symbol': 'btcusd',
#   'time': 1368403200000,
#   'open': 115.97,
#   'close': 117.979,
#   'high': 118.97,
#   'low': 114.07,
#   'volume': 2590.84616000999},
#  {'symbol': 'btcusd',
#   'time': 1368489600000,
#   'open': 117.811,
#   'close': 111.551,
#   'high': 119.85,
#   'low': 105.2,
#   'volume': 9787.13803173999},
#  {'symbol': 'btcusd',
#   'time': 1368576000000,
#   'open': 110.7,
#   'close': 108.95,
#   'high': 117.0,
#   'low': 103.45,
#   'volume': 9324.26007941004},
#  {'symbol': 'btcusd',
#   'time': 1368662400000,
#   'open': 108.98,
#   'close': 115.0,
#   'high': 115.2,
#   'low': 108.2,
#   'volume': 4796.42398125},
#  {'symbol': 'btcusd',
#   'time': 1368748800000,
#   'open': 115.0,
#   'close': 117.62,
#   'high': 122.0,
#   'low': 112.35,
#   'volume': 5107.8367596},
#  {'symbol': 'btcusd',
#   'time': 1368835200000,
#   'open': 117.51,
#   'close': 118.52,
#   'high': 118.98,
#   'low': 115.81001,
#   'volume': 2168.44858122},
#  {'symbol': 'btcusd',
#   'time': 1368921600000,
#   'open': 118.23,
#   'close': 118.25,
#   'high': 120.99,
#   'low': 115.61,
#   'volume': 1327.45239545},
#  {'symbol': 'btcusd',
#   'time': 1369008000000,
#   'open': 118.23,
#   'close': 118.09,
#   'high': 118.94,
#   'low': 116.0,
#   'volume': 881.057857620001},
#  {'symbol': 'btcusd',
#   'time': 1369094400000,
#   'open': 116.9,
#   'close': 117.0,
#   'high': 118.6,
#   'low': 116.9,
#   'volume': 1897.54839262},
#  {'symbol': 'btcusd',
#   'time': 1369180800000,
#   'open': 117.9,
#   'close': 119.11,
#   'high': 120.0,
#   'low': 117.0,
#   'volume': 2360.34984014},
#  {'symbol': 'btcusd',
#   'time': 1369267200000,
#   'open': 118.45,
#   'close': 123.83,
#   'high': 124.25,
#   'low': 118.41,
#   'volume': 4024.65733015},
#  {'symbol': 'btcusd',
#   'time': 1369353600000,
#   'open': 123.84,
#   'close': 128.7,
#   'high': 130.0,
#   'low': 122.4,
#   'volume': 7965.53671446005},
#  {'symbol': 'btcusd',
#   'time': 1369440000000,
#   'open': 128.61,
#   'close': 128.97,
#   'high': 129.73,
#   'low': 125.1,
#   'volume': 2715.80561304},
#  {'symbol': 'btcusd',
#   'time': 1369526400000,
#   'open': 128.97,
#   'close': 130.24,
#   'high': 133.0,
#   'low': 128.0,
#   'volume': 2883.23013612999},
#  {'symbol': 'btcusd',
#   'time': 1369612800000,
#   'open': 130.27,
#   'close': 126.25,
#   'high': 130.59,
#   'low': 123.0,
#   'volume': 3535.31536517},
#  {'symbol': 'btcusd',
#   'time': 1369699200000,
#   'open': 125.0,
#   'close': 125.5,
#   'high': 127.0,
#   'low': 123.0,
#   'volume': 2584.01718862999},
#  {'symbol': 'btcusd',
#   'time': 1369785600000,
#   'open': 126.06,
#   'close': 130.35,
#   'high': 140.68,
#   'low': 125.67,
#   'volume': 3558.61656252},
#  {'symbol': 'btcusd',
#   'time': 1369872000000,
#   'open': 130.35,
#   'close': 126.7,
#   'high': 131.0,
#   'low': 124.15,
#   'volume': 4729.10265707},
#  {'symbol': 'btcusd',
#   'time': 1369958400000,
#   'open': 126.78,
#   'close': 127.9,
#   'high': 129.1,
#   'low': 125.06,
#   'volume': 2267.47870654},
#  {'symbol': 'btcusd',
#   'time': 1370044800000,
#   'open': 127.73,
#   'close': 128.77,
#   'high': 129.0,
#   'low': 127.0,
#   'volume': 815.111739319999},
#  {'symbol': 'btcusd',
#   'time': 1370131200000,
#   'open': 128.77,
#   'close': 123.8,
#   'high': 132.65,
#   'low': 117.0,
#   'volume': 11892.97161185},
#  {'symbol': 'btcusd',
#   'time': 1370217600000,
#   'open': 123.41,
#   'close': 123.1,
#   'high': 132.87,
#   'low': 117.0,
#   'volume': 4750.35164634001},
#  {'symbol': 'btcusd',
#   'time': 1370304000000,
#   'open': 123.22,
#   'close': 120.43,
#   'high': 123.99,
#   'low': 116.42,
#   'volume': 5195.53171193999},
#  {'symbol': 'btcusd',
#   'time': 1370390400000,
#   'open': 120.3,
#   'close': 121.19,
#   'high': 122.37,
#   'low': 119.6,
#   'volume': 1435.87228074},
#  {'symbol': 'btcusd',
#   'time': 1370476800000,
#   'open': 121.33,
#   'close': 119.28,
#   'high': 121.33,
#   'low': 118.0,
#   'volume': 1260.70737532},
#  {'symbol': 'btcusd',
#   'time': 1370563200000,
#   'open': 118.4,
#   'close': 111.07,
#   'high': 119.0,
#   'low': 107.0,
#   'volume': 9638.20980937},
#  {'symbol': 'btcusd',
#   'time': 1370649600000,
#   'open': 110.17,
#   'close': 109.13,
#   'high': 112.5,
#   'low': 108.45,
#   'volume': 1943.22231781998},
#  {'symbol': 'btcusd',
#   'time': 1370736000000,
#   'open': 108.99,
#   'close': 100.0,
#   'high': 110.0,
#   'low': 89.9,
#   'volume': 15769.8720150199},
#  {'symbol': 'btcusd',
#   'time': 1370822400000,
#   'open': 100.0,
#   'close': 104.18,
#   'high': 108.0,
#   'low': 93.0,
#   'volume': 9456.96656614999},
#  {'symbol': 'btcusd',
#   'time': 1370908800000,
#   'open': 104.68,
#   'close': 107.36,
#   'high': 108.03,
#   'low': 103.4,
#   'volume': 3419.50826205},
#  {'symbol': 'btcusd',
#   'time': 1370995200000,
#   'open': 107.07,
#   'close': 106.68,
#   'high': 119.0,
#   'low': 105.0,
#   'volume': 4657.07381088},
#  {'symbol': 'btcusd',
#   'time': 1371081600000,
#   'open': 106.28,
#   'close': 102.0,
#   'high': 109.14,
#   'low': 95.0,
#   'volume': 5813.81744085001},
#  {'symbol': 'btcusd',
#   'time': 1371168000000,
#   'open': 101.86,
#   'close': 99.0,
#   'high': 107.36,
#   'low': 97.0,
#   'volume': 5295.67898359999},
#  {'symbol': 'btcusd',
#   'time': 1371254400000,
#   'open': 99.01,
#   'close': 99.42,
#   'high': 104.0,
#   'low': 96.22,
#   'volume': 2397.84888941},
#  {'symbol': 'btcusd',
#   'time': 1371340800000,
#   'open': 99.43,
#   'close': 99.0,
#   'high': 101.1,
#   'low': 98.66,
#   'volume': 1192.21017157},
#  {'symbol': 'btcusd',
#   'time': 1371427200000,
#   'open': 99.0,
#   'close': 100.49,
#   'high': 101.01,
#   'low': 98.3,
#   'volume': 1286.44020787},
#  {'symbol': 'btcusd',
#   'time': 1371513600000,
#   'open': 100.39,
#   'close': 104.12,
#   'high': 108.5,
#   'low': 99.99,
#   'volume': 6069.10417773999},
#  {'symbol': 'btcusd',
#   'time': 1371600000000,
#   'open': 104.49,
#   'close': 104.99,
#   'high': 107.5,
#   'low': 102.99,
#   'volume': 2830.34656024},
#  {'symbol': 'btcusd',
#   'time': 1371686400000,
#   'open': 104.83,
#   'close': 104.55,
#   'high': 108.0,
#   'low': 102.38,
#   'volume': 5580.15645347},
#  {'symbol': 'btcusd',
#   'time': 1371772800000,
#   'open': 103.0,
#   'close': 101.29,
#   'high': 105.0,
#   'low': 91.0,
#   'volume': 5584.19399546001},
#  {'symbol': 'btcusd',
#   'time': 1371859200000,
#   'open': 101.29,
#   'close': 100.23,
#   'high': 102.4,
#   'low': 98.49,
#   'volume': 1390.41839215},
#  {'symbol': 'btcusd',
#   'time': 1371945600000,
#   'open': 100.0,
#   'close': 100.4,
#   'high': 101.5,
#   'low': 98.6,
#   'volume': 796.29810476},
#  {'symbol': 'btcusd',
#   'time': 1372032000000,
#   'open': 100.4,
#   'close': 98.68,
#   'high': 102.13,
#   'low': 95.38,
#   'volume': 2801.04700209},
#  {'symbol': 'btcusd',
#   'time': 1372118400000,
#   'open': 99.35,
#   'close': 97.58,
#   'high': 100.9,
#   'low': 97.5,
#   'volume': 3395.16434416},
#  {'symbol': 'btcusd',
#   'time': 1372204800000,
#   'open': 98.5,
#   'close': 98.69,
#   'high': 100.0,
#   'low': 96.99,
#   'volume': 1466.12790174},
#  {'symbol': 'btcusd',
#   'time': 1372291200000,
#   'open': 98.01,
#   'close': 96.31,
#   'high': 98.72,
#   'low': 96.31,
#   'volume': 1085.47473304},
#  {'symbol': 'btcusd',
#   'time': 1372377600000,
#   'open': 96.31,
#   'close': 89.79,
#   'high': 96.52,
#   'low': 88.01,
#   'volume': 7594.03228208003},
#  {'symbol': 'btcusd',
#   'time': 1372464000000,
#   'open': 89.2,
#   'close': 88.8,
#   'high': 91.6,
#   'low': 86.15,
#   'volume': 1766.18636145999},
#  {'symbol': 'btcusd',
#   'time': 1372550400000,
#   'open': 88.53,
#   'close': 89.55,
#   'high': 90.25,
#   'low': 88.26,
#   'volume': 525.54269882},
#  {'symbol': 'btcusd',
#   'time': 1372636800000,
#   'open': 89.58,
#   'close': 83.5,
#   'high': 91.56,
#   'low': 1.0,
#   'volume': 10021.30520817},
#  {'symbol': 'btcusd',
#   'time': 1372723200000,
#   'open': 83.51,
#   'close': 87.68,
#   'high': 88.5,
#   'low': 83.24,
#   'volume': 3732.32847998},
#  {'symbol': 'btcusd',
#   'time': 1372809600000,
#   'open': 89.0,
#   'close': 77.402,
#   'high': 89.56,
#   'low': 75.0,
#   'volume': 8688.24345300004},
#  {'symbol': 'btcusd',
#   'time': 1372896000000,
#   'open': 77.33,
#   'close': 79.4,
#   'high': 82.0,
#   'low': 70.04,
#   'volume': 7081.44839216002},
#  {'symbol': 'btcusd',
#   'time': 1372982400000,
#   'open': 79.4,
#   'close': 67.0,
#   'high': 79.4,
#   'low': 64.0,
#   'volume': 13816.96117611},
#  {'symbol': 'btcusd',
#   'time': 1373068800000,
#   'open': 67.0,
#   'close': 66.12,
#   'high': 73.26,
#   'low': 62.94,
#   'volume': 10426.96530785},
#  {'symbol': 'btcusd',
#   'time': 1373155200000,
#   'open': 66.12,
#   'close': 73.98,
#   'high': 74.07786,
#   'low': 64.89,
#   'volume': 4403.96884005},
#  {'symbol': 'btcusd',
#   'time': 1373241600000,
#   'open': 73.96,
#   'close': 74.35,
#   'high': 77.0,
#   'low': 70.0,
#   'volume': 8789.76770627001},
#  {'symbol': 'btcusd',
#   'time': 1373328000000,
#   'open': 73.85,
#   'close': 74.98,
#   'high': 76.01,
#   'low': 70.47,
#   'volume': 7041.32536101},
#  {'symbol': 'btcusd',
#   'time': 1373414400000,
#   'open': 74.93,
#   'close': 86.12,
#   'high': 87.0,
#   'low': 74.83,
#   'volume': 10374.85241819},
#  {'symbol': 'btcusd',
#   'time': 1373500800000,
#   'open': 86.12,
#   'close': 88.0,
#   'high': 89.23,
#   'low': 84.0,
#   'volume': 7510.96612628002},
#  {'symbol': 'btcusd',
#   'time': 1373587200000,
#   'open': 87.81,
#   'close': 90.2,
#   'high': 101.39,
#   'low': 86.64,
#   'volume': 15077.5410866301},
#  {'symbol': 'btcusd',
#   'time': 1373673600000,
#   'open': 90.17,
#   'close': 91.6,
#   'high': 91.95,
#   'low': 85.0,
#   'volume': 4116.22796884997},
#  {'symbol': 'btcusd',
#   'time': 1373760000000,
#   'open': 91.69,
#   'close': 90.07,
#   'high': 93.0,
#   'low': 88.88,
#   'volume': 2380.35140134999},
#  {'symbol': 'btcusd',
#   'time': 1373846400000,
#   'open': 89.011,
#   'close': 93.94,
#   'high': 99.83,
#   'low': 82.45,
#   'volume': 5898.45713615004},
#  {'symbol': 'btcusd',
#   'time': 1373932800000,
#   'open': 93.75,
#   'close': 91.6,
#   'high': 94.0,
#   'low': 84.7,
#   'volume': 2092.35853054},
#  {'symbol': 'btcusd',
#   'time': 1374019200000,
#   'open': 91.58,
#   'close': 91.48,
#   'high': 92.8,
#   'low': 89.22,
#   'volume': 2046.72746749},
#  {'symbol': 'btcusd',
#   'time': 1374105600000,
#   'open': 90.85,
#   'close': 85.27,
#   'high': 91.23,
#   'low': 77.0,
#   'volume': 7708.73483260006},
#  {'symbol': 'btcusd',
#   'time': 1374192000000,
#   'open': 85.01,
#   'close': 86.53,
#   'high': 87.1,
#   'low': 83.4,
#   'volume': 4794.18316172001},
#  {'symbol': 'btcusd',
#   'time': 1374278400000,
#   'open': 86.5,
#   'close': 85.0,
#   'high': 87.2,
#   'low': 84.27,
#   'volume': 1301.92237319},
#  {'symbol': 'btcusd',
#   'time': 1374364800000,
#   'open': 85.09,
#   'close': 85.79,
#   'high': 86.4,
#   'low': 84.0,
#   'volume': 2113.51241199},
#  {'symbol': 'btcusd',
#   'time': 1374451200000,
#   'open': 85.77,
#   'close': 85.6,
#   'high': 87.1,
#   'low': 83.99,
#   'volume': 1354.67793009},
#  {'symbol': 'btcusd',
#   'time': 1374537600000,
#   'open': 85.55,
#   'close': 86.95,
#   'high': 88.67,
#   'low': 82.99,
#   'volume': 3368.91523392999},
#  {'symbol': 'btcusd',
#   'time': 1374624000000,
#   'open': 86.95,
#   'close': 88.36,
#   'high': 95.68,
#   'low': 86.46,
#   'volume': 1618.34266729},
#  {'symbol': 'btcusd',
#   'time': 1374710400000,
#   'open': 88.42,
#   'close': 90.24,
#   'high': 91.99899,
#   'low': 87.15,
#   'volume': 3345.36886326999},
#  {'symbol': 'btcusd',
#   'time': 1374796800000,
#   'open': 90.09,
#   'close': 89.95,
#   'high': 91.72,
#   'low': 89.2,
#   'volume': 973.533901570004},
#  {'symbol': 'btcusd',
#   'time': 1374883200000,
#   'open': 89.95,
#   'close': 88.02,
#   'high': 90.11,
#   'low': 87.8,
#   'volume': 1427.28403652},
#  {'symbol': 'btcusd',
#   'time': 1374969600000,
#   'open': 88.02,
#   'close': 92.46,
#   'high': 94.0,
#   'low': 87.92,
#   'volume': 3411.06759993999},
#  {'symbol': 'btcusd',
#   'time': 1375056000000,
#   'open': 92.01,
#   'close': 93.37,
#   'high': 93.73,
#   'low': 90.54,
#   'volume': 2712.34032741},
#  {'symbol': 'btcusd',
#   'time': 1375142400000,
#   'open': 93.01,
#   'close': 96.5,
#   'high': 97.11,
#   'low': 92.7,
#   'volume': 3558.87774625},
#  {'symbol': 'btcusd',
#   'time': 1375228800000,
#   'open': 96.68,
#   'close': 98.18,
#   'high': 101.03,
#   'low': 95.1,
#   'volume': 5708.72022212001},
#  {'symbol': 'btcusd',
#   'time': 1375315200000,
#   'open': 97.99,
#   'close': 96.55,
#   'high': 98.50297,
#   'low': 95.21,
#   'volume': 3534.33334448},
#  {'symbol': 'btcusd',
#   'time': 1375401600000,
#   'open': 96.55,
#   'close': 95.85,
#   'high': 98.7,
#   'low': 93.75,
#   'volume': 5444.95317152999},
#  {'symbol': 'btcusd',
#   'time': 1375488000000,
#   'open': 95.82,
#   'close': 95.49,
#   'high': 97.23,
#   'low': 94.67,
#   'volume': 2406.7126632},
#  {'symbol': 'btcusd',
#   'time': 1375574400000,
#   'open': 95.5,
#   'close': 96.38,
#   'high': 96.7,
#   'low': 95.5,
#   'volume': 1011.16940019},
#  {'symbol': 'btcusd',
#   'time': 1375660800000,
#   'open': 96.38,
#   'close': 97.4,
#   'high': 98.91,
#   'low': 96.21,
#   'volume': 2944.54669789999},
#  {'symbol': 'btcusd',
#   'time': 1375747200000,
#   'open': 97.73,
#   'close': 97.8,
#   'high': 98.9,
#   'low': 97.0,
#   'volume': 2531.28944375},
#  {'symbol': 'btcusd',
#   'time': 1375833600000,
#   'open': 97.8,
#   'close': 97.0,
#   'high': 98.3,
#   'low': 95.5,
#   'volume': 1576.176273},
#  {'symbol': 'btcusd',
#   'time': 1375920000000,
#   'open': 97.0,
#   'close': 94.25,
#   'high': 97.17,
#   'low': 91.4,
#   'volume': 4701.13478028},
#  {'symbol': 'btcusd',
#   'time': 1376006400000,
#   'open': 94.27,
#   'close': 92.28,
#   'high': 95.51,
#   'low': 89.51,
#   'volume': 5799.07629595998},
#  {'symbol': 'btcusd',
#   'time': 1376092800000,
#   'open': 92.14,
#   'close': 93.51,
#   'high': 94.0,
#   'low': 92.14,
#   'volume': 754.8018569},
#  {'symbol': 'btcusd',
#   'time': 1376179200000,
#   'open': 93.51,
#   'close': 94.0,
#   'high': 94.52,
#   'low': 93.2,
#   'volume': 703.22305316},
#  {'symbol': 'btcusd',
#   'time': 1376265600000,
#   'open': 94.0,
#   'close': 95.35,
#   'high': 96.24,
#   'low': 93.31,
#   'volume': 2950.84243716999},
#  {'symbol': 'btcusd',
#   'time': 1376352000000,
#   'open': 95.12109,
#   'close': 98.15,
#   'high': 98.2,
#   'low': 94.23,
#   'volume': 3644.09122657},
#  {'symbol': 'btcusd',
#   'time': 1376438400000,
#   'open': 97.99,
#   'close': 99.16,
#   'high': 101.0,
#   'low': 97.36828,
#   'volume': 7832.14442446},
#  {'symbol': 'btcusd',
#   'time': 1376524800000,
#   'open': 99.4,
#   'close': 98.08,
#   'high': 100.01,
#   'low': 96.24,
#   'volume': 1749.74382402},
#  {'symbol': 'btcusd',
#   'time': 1376611200000,
#   'open': 98.39,
#   'close': 98.3,
#   'high': 99.0,
#   'low': 96.53,
#   'volume': 1945.81185098},
#  {'symbol': 'btcusd',
#   'time': 1376697600000,
#   'open': 98.27,
#   'close': 99.4,
#   'high': 99.7,
#   'low': 97.5,
#   'volume': 1601.91017454},
#  {'symbol': 'btcusd',
#   'time': 1376784000000,
#   'open': 100.0,
#   'close': 99.25,
#   'high': 100.0,
#   'low': 98.42,
#   'volume': 929.14723601},
#  {'symbol': 'btcusd',
#   'time': 1376870400000,
#   'open': 99.25,
#   'close': 102.6,
#   'high': 105.0,
#   'low': 98.82,
#   'volume': 7038.31706310001},
#  {'symbol': 'btcusd',
#   'time': 1376956800000,
#   'open': 102.85,
#   'close': 104.94,
#   'high': 104.94,
#   'low': 100.48,
#   'volume': 3887.65063900999},
#  {'symbol': 'btcusd',
#   'time': 1377043200000,
#   'open': 104.94,
#   'close': 110.43,
#   'high': 114.45,
#   'low': 104.57,
#   'volume': 9461.08726163004},
#  {'symbol': 'btcusd',
#   'time': 1377129600000,
#   'open': 111.62,
#   'close': 109.14,
#   'high': 113.01,
#   'low': 107.99,
#   'volume': 4026.72231985},
#  {'symbol': 'btcusd',
#   'time': 1377216000000,
#   'open': 109.12,
#   'close': 107.89,
#   'high': 110.0,
#   'low': 104.3,
#   'volume': 5316.11409683},
#  {'symbol': 'btcusd',
#   'time': 1377302400000,
#   'open': 107.66,
#   'close': 108.3,
#   'high': 110.6,
#   'low': 106.61,
#   'volume': 2760.95065165},
#  {'symbol': 'btcusd',
#   'time': 1377388800000,
#   'open': 109.17,
#   'close': 113.11,
#   'high': 114.76,
#   'low': 109.16,
#   'volume': 5981.71180220001},
#  {'symbol': 'btcusd',
#   'time': 1377475200000,
#   'open': 113.12,
#   'close': 112.45,
#   'high': 113.9,
#   'low': 110.0,
#   'volume': 4105.75356866},
#  {'symbol': 'btcusd',
#   'time': 1377561600000,
#   'open': 111.85,
#   'close': 117.7,
#   'high': 119.0,
#   'low': 111.77,
#   'volume': 8861.29718058001},
#  {'symbol': 'btcusd',
#   'time': 1377648000000,
#   'open': 118.0,
#   'close': 118.0,
#   'high': 119.76,
#   'low': 116.0,
#   'volume': 3508.16170538},
#  {'symbol': 'btcusd',
#   'time': 1377734400000,
#   'open': 117.95,
#   'close': 118.5,
#   'high': 121.0,
#   'low': 117.29,
#   'volume': 2722.03372053},
#  {'symbol': 'btcusd',
#   'time': 1377820800000,
#   'open': 118.93,
#   'close': 125.0,
#   'high': 126.3,
#   'low': 118.05,
#   'volume': 9634.03948353002},
#  {'symbol': 'btcusd',
#   'time': 1377907200000,
#   'open': 124.89,
#   'close': 127.8,
#   'high': 134.94,
#   'low': 123.75,
#   'volume': 12537.83420063},
#  {'symbol': 'btcusd',
#   'time': 1377993600000,
#   'open': 128.21,
#   'close': 130.41,
#   'high': 132.0,
#   'low': 126.81,
#   'volume': 2117.60762314},
#  {'symbol': 'btcusd',
#   'time': 1378080000000,
#   'open': 130.73,
#   'close': 129.45,
#   'high': 132.05,
#   'low': 128.0,
#   'volume': 4229.80472060998},
#  {'symbol': 'btcusd',
#   'time': 1378166400000,
#   'open': 129.23,
#   'close': 129.18,
#   'high': 131.0,
#   'low': 126.9,
#   'volume': 3621.71363355999},
#  {'symbol': 'btcusd',
#   'time': 1378252800000,
#   'open': 130.0,
#   'close': 122.24,
#   'high': 130.0,
#   'low': 115.0,
#   'volume': 9377.23333298001},
#  {'symbol': 'btcusd',
#   'time': 1378339200000,
#   'open': 122.22,
#   'close': 122.63,
#   'high': 127.99,
#   'low': 115.81,
#   'volume': 7294.63083097997},
#  {'symbol': 'btcusd',
#   'time': 1378425600000,
#   'open': 122.0,
#   'close': 116.82,
#   'high': 124.75,
#   'low': 115.0,
#   'volume': 5683.34157264999},
#  {'symbol': 'btcusd',
#   'time': 1378512000000,
#   'open': 116.0,
#   'close': 119.76,
#   'high': 121.10889,
#   'low': 115.5,
#   'volume': 2899.83061763999},
#  {'symbol': 'btcusd',
#   'time': 1378598400000,
#   'open': 119.79,
#   'close': 117.98,
#   'high': 120.84,
#   'low': 116.77,
#   'volume': 2707.40051492},
#  {'symbol': 'btcusd',
#   'time': 1378684800000,
#   'open': 118.0,
#   'close': 121.5,
#   'high': 124.0,
#   'low': 115.98561,
#   'volume': 8252.05121633003},
#  {'symbol': 'btcusd',
#   'time': 1378771200000,
#   'open': 121.17,
#   'close': 122.07,
#   'high': 124.24,
#   'low': 120.07,
#   'volume': 3626.92833386999},
#  {'symbol': 'btcusd',
#   'time': 1378857600000,
#   'open': 122.34,
#   'close': 126.34,
#   'high': 127.64,
#   'low': 118.39,
#   'volume': 9078.22123422003},
#  {'symbol': 'btcusd',
#   'time': 1378944000000,
#   'open': 126.92,
#   'close': 126.63,
#   'high': 128.5,
#   'low': 123.0,
#   'volume': 5161.99913747999},
#  {'symbol': 'btcusd',
#   'time': 1379030400000,
#   'open': 126.63,
#   'close': 127.18,
#   'high': 129.11,
#   'low': 124.82,
#   'volume': 2524.77115444},
#  {'symbol': 'btcusd',
#   'time': 1379116800000,
#   'open': 126.23,
#   'close': 124.5,
#   'high': 127.98,
#   'low': 122.53,
#   'volume': 3550.48828070999},
#  {'symbol': 'btcusd',
#   'time': 1379203200000,
#   'open': 124.5,
#   'close': 125.06,
#   'high': 126.35,
#   'low': 123.15,
#   'volume': 1973.20832033},
#  {'symbol': 'btcusd',
#   'time': 1379289600000,
#   'open': 125.18,
#   'close': 125.68,
#   'high': 126.84,
#   'low': 124.0,
#   'volume': 1710.23628094},
#  {'symbol': 'btcusd',
#   'time': 1379376000000,
#   'open': 126.15,
#   'close': 127.13,
#   'high': 127.74,
#   'low': 125.32,
#   'volume': 1790.28239465},
#  {'symbol': 'btcusd',
#   'time': 1379462400000,
#   'open': 126.72,
#   'close': 126.9,
#   'high': 128.41,
#   'low': 125.78,
#   'volume': 3950.89185976},
#  {'symbol': 'btcusd',
#   'time': 1379548800000,
#   'open': 127.0,
#   'close': 124.38,
#   'high': 127.63,
#   'low': 123.39,
#   'volume': 3443.87264583},
#  {'symbol': 'btcusd',
#   'time': 1379635200000,
#   'open': 123.8,
#   'close': 122.91,
#   'high': 126.01,
#   'low': 121.5,
#   'volume': 3838.92105376999},
#  {'symbol': 'btcusd',
#   'time': 1379721600000,
#   'open': 122.92,
#   'close': 123.64,
#   'high': 124.02,
#   'low': 122.0,
#   'volume': 1023.90288201},
#  {'symbol': 'btcusd',
#   'time': 1379808000000,
#   'open': 123.5,
#   'close': 122.97,
#   'high': 123.59,
#   'low': 122.22,
#   'volume': 1078.48505357},
#  {'symbol': 'btcusd',
#   'time': 1379894400000,
#   'open': 122.93,
#   'close': 122.75,
#   'high': 124.09,
#   'low': 122.0,
#   'volume': 2465.01122629},
#  {'symbol': 'btcusd',
#   'time': 1379980800000,
#   'open': 123.0,
#   'close': 124.09,
#   'high': 124.19,
#   'low': 121.89,
#   'volume': 3165.47374378},
#  {'symbol': 'btcusd',
#   'time': 1380067200000,
#   'open': 123.89,
#   'close': 123.75,
#   'high': 125.22,
#   'low': 123.35,
#   'volume': 1900.35140246},
#  {'symbol': 'btcusd',
#   'time': 1380153600000,
#   'open': 123.32,
#   'close': 125.02,
#   'high': 125.02,
#   'low': 123.3,
#   'volume': 1002.22446382},
#  {'symbol': 'btcusd',
#   'time': 1380240000000,
#   'open': 124.4,
#   'close': 126.48,
#   'high': 126.86,
#   'low': 124.1,
#   'volume': 2578.6923297},
#  {'symbol': 'btcusd',
#   'time': 1380326400000,
#   'open': 126.57,
#   'close': 127.0,
#   'high': 127.0,
#   'low': 124.8,
#   'volume': 2488.46477039},
#  {'symbol': 'btcusd',
#   'time': 1380412800000,
#   'open': 126.87,
#   'close': 126.76,
#   'high': 128.8,
#   'low': 126.0,
#   'volume': 3011.13758087},
#  {'symbol': 'btcusd',
#   'time': 1380499200000,
#   'open': 127.0,
#   'close': 125.95,
#   'high': 127.51,
#   'low': 123.76,
#   'volume': 3072.55201951},
#  {'symbol': 'btcusd',
#   'time': 1380585600000,
#   'open': 125.95,
#   'close': 127.49,
#   'high': 127.9399,
#   'low': 125.81,
#   'volume': 2151.64918807},
#  {'symbol': 'btcusd',
#   'time': 1380672000000,
#   'open': 127.2,
#   'close': 103.85,
#   'high': 128.5,
#   'low': 83.26,
#   'volume': 38763.0172714799},
#  {'symbol': 'btcusd',
#   'time': 1380758400000,
#   'open': 103.99,
#   'close': 117.87,
#   'high': 118.74,
#   'low': 101.66,
#   'volume': 11393.82089187},
#  {'symbol': 'btcusd',
#   'time': 1380844800000,
#   'open': 117.87,
#   'close': 121.94,
#   'high': 123.25,
#   'low': 117.41,
#   'volume': 6632.39275909002},
#  {'symbol': 'btcusd',
#   'time': 1380931200000,
#   'open': 121.94,
#   'close': 121.62,
#   'high': 125.0,
#   'low': 115.0,
#   'volume': 1451.61906773},
#  {'symbol': 'btcusd',
#   'time': 1381017600000,
#   'open': 121.14,
#   'close': 122.49,
#   'high': 122.5,
#   'low': 121.01,
#   'volume': 399.440586},
#  {'symbol': 'btcusd',
#   'time': 1381104000000,
#   'open': 122.26,
#   'close': 123.48,
#   'high': 124.45,
#   'low': 120.8,
#   'volume': 4205.69134063},
#  {'symbol': 'btcusd',
#   'time': 1381190400000,
#   'open': 123.5,
#   'close': 124.11,
#   'high': 125.16,
#   'low': 122.02,
#   'volume': 5205.68123215999},
#  {'symbol': 'btcusd',
#   'time': 1381276800000,
#   'open': 124.4,
#   'close': 126.00071,
#   'high': 127.99,
#   'low': 123.36,
#   'volume': 6494.56802603001},
#  {'symbol': 'btcusd',
#   'time': 1381363200000,
#   'open': 125.67,
#   'close': 126.1,
#   'high': 126.79,
#   'low': 125.0,
#   'volume': 2321.77150535999},
#  {'symbol': 'btcusd',
#   'time': 1381449600000,
#   'open': 126.46,
#   'close': 126.9,
#   'high': 127.4,
#   'low': 125.54,
#   'volume': 2177.80246511},
#  {'symbol': 'btcusd',
#   'time': 1381536000000,
#   'open': 126.9,
#   'close': 127.8,
#   'high': 127.96,
#   'low': 126.65,
#   'volume': 1651.53519078},
#  {'symbol': 'btcusd',
#   'time': 1381622400000,
#   'open': 127.6,
#   'close': 132.86,
#   'high': 133.23,
#   'low': 127.55,
#   'volume': 6020.83465236},
#  {'symbol': 'btcusd',
#   'time': 1381708800000,
#   'open': 132.6,
#   'close': 135.4,
#   'high': 139.99,
#   'low': 132.0,
#   'volume': 12310.3421481001},
#  {'symbol': 'btcusd',
#   'time': 1381795200000,
#   'open': 135.47,
#   'close': 144.39,
#   'high': 150.0,
#   'low': 134.09,
#   'volume': 10815.77840346},
#  {'symbol': 'btcusd',
#   'time': 1381881600000,
#   'open': 144.39,
#   'close': 137.56,
#   'high': 147.0,
#   'low': 137.21,
#   'volume': 15517.28434985},
#  {'symbol': 'btcusd',
#   'time': 1381968000000,
#   'open': 137.54,
#   'close': 143.94,
#   'high': 144.98,
#   'low': 133.99,
#   'volume': 5237.28751872},
#  {'symbol': 'btcusd',
#   'time': 1382054400000,
#   'open': 143.49,
#   'close': 153.0,
#   'high': 155.25,
#   'low': 143.0,
#   'volume': 14115.9018835201},
#  {'symbol': 'btcusd',
#   'time': 1382140800000,
#   'open': 152.89,
#   'close': 166.5,
#   'high': 178.5,
#   'low': 151.5,
#   'volume': 20875.7260725199},
#  {'symbol': 'btcusd',
#   'time': 1382227200000,
#   'open': 168.0,
#   'close': 166.89,
#   'high': 168.875,
#   'low': 162.31,
#   'volume': 3857.31917752},
#  {'symbol': 'btcusd',
#   'time': 1382313600000,
#   'open': 166.44,
#   'close': 180.37,
#   'high': 183.0,
#   'low': 166.0,
#   'volume': 12821.42817668},
#  {'symbol': 'btcusd',
#   'time': 1382400000000,
#   'open': 180.5,
#   'close': 191.75,
#   'high': 215.0,
#   'low': 179.1,
#   'volume': 18464.69246628},
#  {'symbol': 'btcusd',
#   'time': 1382486400000,
#   'open': 194.5,
#   'close': 203.99,
#   'high': 212.89,
#   'low': 187.0,
#   'volume': 13848.1826281501},
#  {'symbol': 'btcusd',
#   'time': 1382572800000,
#   'open': 204.5,
#   'close': 193.72,
#   'high': 210.995,
#   'low': 155.81,
#   'volume': 41374.6601641995},
#  {'symbol': 'btcusd',
#   'time': 1382659200000,
#   'open': 194.0,
#   'close': 187.5,
#   'high': 195.13,
#   'low': 167.75,
#   'volume': 20163.72357838},
#  {'symbol': 'btcusd',
#   'time': 1382745600000,
#   'open': 186.62,
#   'close': 179.55,
#   'high': 190.0,
#   'low': 175.21,
#   'volume': 6283.29915677999},
#  {'symbol': 'btcusd',
#   'time': 1382832000000,
#   'open': 179.56,
#   'close': 196.7,
#   'high': 198.75,
#   'low': 179.1,
#   'volume': 6583.20965814008},
#  {'symbol': 'btcusd',
#   'time': 1382918400000,
#   'open': 196.0,
#   'close': 196.01,
#   'high': 199.0,
#   'low': 192.15,
#   'volume': 5605.26249360001},
#  {'symbol': 'btcusd',
#   'time': 1383004800000,
#   'open': 196.01,
#   'close': 204.69,
#   'high': 205.0,
#   'low': 195.37,
#   'volume': 8092.44617620002},
#  {'symbol': 'btcusd',
#   'time': 1383091200000,
#   'open': 203.7,
#   'close': 198.74,
#   'high': 206.0,
#   'low': 195.05,
#   'volume': 14204.4054380701},
#  {'symbol': 'btcusd',
#   'time': 1383177600000,
#   'open': 198.7,
#   'close': 202.52,
#   'high': 204.0,
#   'low': 195.28,
#   'volume': 5287.08851334},
#  {'symbol': 'btcusd',
#   'time': 1383264000000,
#   'open': 203.79,
#   'close': 201.754999,
#   'high': 204.0,
#   'low': 200.5,
#   'volume': 1950.88533844},
#  {'symbol': 'btcusd',
#   'time': 1383350400000,
#   'open': 202.24,
#   'close': 204.94,
#   'high': 205.79,
#   'low': 201.33,
#   'volume': 4054.66482564999},
#  {'symbol': 'btcusd',
#   'time': 1383436800000,
#   'open': 204.67,
#   'close': 213.8975,
#   'high': 219.89,
#   'low': 203.0,
#   'volume': 4806.65527203001},
#  {'symbol': 'btcusd',
#   'time': 1383523200000,
#   'open': 213.949,
#   'close': 226.5049999,
#   'high': 230.5,
#   'low': 211.0,
#   'volume': 11528.7620527202},
#  {'symbol': 'btcusd',
#   'time': 1383609600000,
#   'open': 227.29,
#   'close': 242.88,
#   'high': 250.75,
#   'low': 225.44,
#   'volume': 23917.3706320101},
#  {'symbol': 'btcusd',
#   'time': 1383696000000,
#   'open': 242.6,
#   'close': 263.24,
#   'high': 265.0,
#   'low': 240.6,
#   'volume': 27950.6772529572},
#  {'symbol': 'btcusd',
#   'time': 1383782400000,
#   'open': 263.5,
#   'close': 291.0,
#   'high': 297.79,
#   'low': 262.0,
#   'volume': 35703.8390349999},
#  {'symbol': 'btcusd',
#   'time': 1383868800000,
#   'open': 290.8,
#   'close': 333.9,
#   'high': 334.95,
#   'low': 288.89,
#   'volume': 22587.4898973999},
#  {'symbol': 'btcusd',
#   'time': 1383955200000,
#   'open': 333.9,
#   'close': 338.22941,
#   'high': 386.0,
#   'low': 297.0,
#   'volume': 30872.0185769997},
#  {'symbol': 'btcusd',
#   'time': 1384041600000,
#   'open': 339.39,
#   'close': 325.0,
#   'high': 340.0,
#   'low': 265.11,
#   'volume': 35022.9775918295},
#  {'symbol': 'btcusd',
#   'time': 1384128000000,
#   'open': 322.24,
#   'close': 344.27,
#   'high': 357.95,
#   'low': 311.56,
#   'volume': 10389.98799285},
#  {'symbol': 'btcusd',
#   'time': 1384214400000,
#   'open': 347.0,
#   'close': 354.96,
#   'high': 400.0,
#   'low': 340.0,
#   'volume': 13163.9526282},
#  {'symbol': 'btcusd',
#   'time': 1384300800000,
#   'open': 355.45,
#   'close': 399.9,
#   'high': 414.73,
#   'low': 355.45,
#   'volume': 13150.8551845401},
#  {'symbol': 'btcusd',
#   'time': 1384387200000,
#   'open': 399.89,
#   'close': 413.53499,
#   'high': 423.5,
#   'low': 392.8,
#   'volume': 14424.4618612601},
#  {'symbol': 'btcusd',
#   'time': 1384473600000,
#   'open': 415.16,
#   'close': 412.0,
#   'high': 439.94,
#   'low': 388.011,
#   'volume': 17611.6002543102},
#  {'symbol': 'btcusd',
#   'time': 1384560000000,
#   'open': 412.0,
#   'close': 434.52,
#   'high': 448.95,
#   'low': 410.0,
#   'volume': 9971.61084252013},
#  {'symbol': 'btcusd',
#   'time': 1384646400000,
#   'open': 434.53,
#   'close': 492.0,
#   'high': 499.99,
#   'low': 434.53,
#   'volume': 9939.60554958022},
#  {'symbol': 'btcusd',
#   'time': 1384732800000,
#   'open': 492.39,
#   'close': 689.0,
#   'high': 775.0,
#   'low': 490.11,
#   'volume': 22783.1345659296},
#  {'symbol': 'btcusd',
#   'time': 1384819200000,
#   'open': 690.0,
#   'close': 537.0,
#   'high': 909.0,
#   'low': 360.0,
#   'volume': 36107.292589809},
#  {'symbol': 'btcusd',
#   'time': 1384905600000,
#   'open': 535.01,
#   'close': 599.12,
#   'high': 630.0,
#   'low': 450.01,
#   'volume': 27939.0919929797},
#  {'symbol': 'btcusd',
#   'time': 1384992000000,
#   'open': 599.12,
#   'close': 730.0,
#   'high': 745.0,
#   'low': 589.9,
#   'volume': 17157.1255340001},
#  {'symbol': 'btcusd',
#   'time': 1385078400000,
#   'open': 727.0301,
#   'close': 806.3,
#   'high': 839.77,
#   'low': 682.32,
#   'volume': 12996.9952893601},
#  {'symbol': 'btcusd',
#   'time': 1385164800000,
#   'open': 815.0,
#   'close': 847.666666,
#   'high': 886.876543,
#   'low': 775.0,
#   'volume': 9697.72957536012},
#  {'symbol': 'btcusd',
#   'time': 1385251200000,
#   'open': 847.5,
#   'close': 815.0,
#   'high': 860.0,
#   'low': 745.0,
#   'volume': 11931.4688187901},
#  {'symbol': 'btcusd',
#   'time': 1385337600000,
#   'open': 814.16,
#   'close': 818.98,
#   'high': 844.579,
#   'low': 768.0,
#   'volume': 9443.71409179005},
#  {'symbol': 'btcusd',
#   'time': 1385424000000,
#   'open': 813.14,
#   'close': 952.0,
#   'high': 960.0,
#   'low': 800.0,
#   'volume': 10075.5972455901},
#  {'symbol': 'btcusd',
#   'time': 1385510400000,
#   'open': 955.01,
#   'close': 963.0,
#   'high': 969.99,
#   'low': 894.0,
#   'volume': 13045.7822418601},
#  {'symbol': 'btcusd',
#   'time': 1385596800000,
#   'open': 962.01,
#   'close': 1016.1,
#   'high': 1050.34,
#   'low': 945.0,
#   'volume': 9436.59098362006},
#  {'symbol': 'btcusd',
#   'time': 1385683200000,
#   'open': 1015.79,
#   'close': 1132.0,
#   'high': 1142.0,
#   'low': 999.12,
#   'volume': 9112.60453110012},
#  {'symbol': 'btcusd',
#   'time': 1385769600000,
#   'open': 1131.0,
#   'close': 1119.52,
#   'high': 1171.25,
#   'low': 1090.0,
#   'volume': 4977.05940607003},
#  {'symbol': 'btcusd',
#   'time': 1385856000000,
#   'open': 1119.8,
#   'close': 955.0,
#   'high': 1126.0,
#   'low': 780.0,
#   'volume': 31224.8478054497},
#  {'symbol': 'btcusd',
#   'time': 1385942400000,
#   'open': 950.2601,
#   'close': 1037.07,
#   'high': 1059.0,
#   'low': 936.0,
#   'volume': 12076.8095723901},
#  {'symbol': 'btcusd',
#   'time': 1386028800000,
#   'open': 1037.11,
#   'close': 1055.0,
#   'high': 1089.88,
#   'low': 1000.0,
#   'volume': 5606.71756720002},
#  {'symbol': 'btcusd',
#   'time': 1386115200000,
#   'open': 1055.0,
#   'close': 1138.5,
#   'high': 1175.0,
#   'low': 1051.0,
#   'volume': 6797.52731543003},
#  {'symbol': 'btcusd',
#   'time': 1386201600000,
#   'open': 1135.0,
#   'close': 1023.87,
#   'high': 1141.0,
#   'low': 848.42,
#   'volume': 23511.6459976001},
#  {'symbol': 'btcusd',
#   'time': 1386288000000,
#   'open': 1029.02,
#   'close': 820.0,
#   'high': 1032.04,
#   'low': 790.0,
#   'volume': 28781.8713168093},
#  {'symbol': 'btcusd',
#   'time': 1386374400000,
#   'open': 815.0,
#   'close': 693.0,
#   'high': 842.23,
#   'low': 538.0,
#   'volume': 43628.1692512094},
#  {'symbol': 'btcusd',
#   'time': 1386460800000,
#   'open': 692.99,
#   'close': 784.9,
#   'high': 790.39,
#   'low': 650.0,
#   'volume': 13381.6509437201},
#  {'symbol': 'btcusd',
#   'time': 1386547200000,
#   'open': 786.0,
#   'close': 899.01,
#   'high': 901.0,
#   'low': 767.21,
#   'volume': 15615.2399101502},
#  {'symbol': 'btcusd',
#   'time': 1386633600000,
#   'open': 899.94,
#   'close': 983.0,
#   'high': 992.0,
#   'low': 895.0,
#   'volume': 11644.1100796201},
#  {'symbol': 'btcusd',
#   'time': 1386720000000,
#   'open': 982.9697,
#   'close': 879.3,
#   'high': 990.0,
#   'low': 804.26,
#   'volume': 15622.9339904401},
#  {'symbol': 'btcusd',
#   'time': 1386806400000,
#   'open': 879.4,
#   'close': 873.0,
#   'high': 893.97,
#   'low': 838.0,
#   'volume': 8407.60530174005},
#  {'symbol': 'btcusd',
#   'time': 1386892800000,
#   'open': 872.97,
#   'close': 885.02,
#   'high': 923.71,
#   'low': 850.02,
#   'volume': 9499.23705098},
#  {'symbol': 'btcusd',
#   'time': 1386979200000,
#   'open': 885.1,
#   'close': 850.78,
#   'high': 888.8970413,
#   'low': 840.0,
#   'volume': 4137.40713281999},
#  {'symbol': 'btcusd',
#   'time': 1387065600000,
#   'open': 854.98,
#   'close': 859.71,
#   'high': 871.8845,
#   'low': 805.0,
#   'volume': 11388.0131782503},
#  {'symbol': 'btcusd',
#   'time': 1387152000000,
#   'open': 860.33,
#   'close': 690.0,
#   'high': 864.0,
#   'low': 650.9088,
#   'volume': 28828.6722447098},
#  {'symbol': 'btcusd',
#   'time': 1387238400000,
#   'open': 690.0,
#   'close': 675.0,
#   'high': 751.0,
#   'low': 613.0,
#   'volume': 24688.82978813},
#  {'symbol': 'btcusd',
#   'time': 1387324800000,
#   'open': 675.0,
#   'close': 520.01,
#   'high': 679.038754,
#   'low': 381.51,
#   'volume': 80358.8141914289},
#  {'symbol': 'btcusd',
#   'time': 1387411200000,
#   'open': 519.74,
#   'close': 684.99,
#   'high': 700.0,
#   'low': 491.0,
#   'volume': 37418.6332647902},
#  {'symbol': 'btcusd',
#   'time': 1387497600000,
#   'open': 685.0,
#   'close': 609.01,
#   'high': 721.0,
#   'low': 570.0,
#   'volume': 26056.0509110787},
#  {'symbol': 'btcusd',
#   'time': 1387584000000,
#   'open': 608.77,
#   'close': 595.03,
#   'high': 649.0,
#   'low': 568.0,
#   'volume': 12661.2382726203},
#  {'symbol': 'btcusd',
#   'time': 1387670400000,
#   'open': 595.06,
#   'close': 614.999,
#   'high': 674.39,
#   'low': 574.0123,
#   'volume': 13689.7033129602},
#  {'symbol': 'btcusd',
#   'time': 1387756800000,
#   'open': 612.66,
#   'close': 654.76,
#   'high': 669.0,
#   'low': 608.01,
#   'volume': 8550.81498574018},
#  {'symbol': 'btcusd',
#   'time': 1387843200000,
#   'open': 654.76,
#   'close': 651.83,
#   'high': 670.0,
#   'low': 627.0,
#   'volume': 6806.64334295007},
#  {'symbol': 'btcusd',
#   'time': 1387929600000,
#   'open': 653.57,
#   'close': 679.5,
#   'high': 681.0,
#   'low': 635.0,
#   'volume': 3822.45516959999},
#  {'symbol': 'btcusd',
#   'time': 1388016000000,
#   'open': 680.78,
#   'close': 757.3889,
#   'high': 764.0,
#   'low': 677.0,
#   'volume': 18161.4852748501},
#  {'symbol': 'btcusd',
#   'time': 1388102400000,
#   'open': 748.48,
#   'close': 720.61,
#   'high': 763.0,
#   'low': 704.0123,
#   'volume': 11270.5220445601},
#  {'symbol': 'btcusd',
#   'time': 1388188800000,
#   'open': 724.75,
#   'close': 712.2,
#   'high': 740.01,
#   'low': 690.0,
#   'volume': 10090.2275591001},
#  {'symbol': 'btcusd',
#   'time': 1388275200000,
#   'open': 715.01,
#   'close': 728.3,
#   'high': 732.0,
#   'low': 700.0123,
#   'volume': 6131.65568200999},
#  {'symbol': 'btcusd',
#   'time': 1388361600000,
#   'open': 726.82,
#   'close': 736.5,
#   'high': 740.62618,
#   'low': 724.73,
#   'volume': 4234.64065429001},
#  {'symbol': 'btcusd',
#   'time': 1388448000000,
#   'open': 735.5,
#   'close': 729.99,
#   'high': 740.0,
#   'low': 710.02,
#   'volume': 8561.28944057009},
#  {'symbol': 'btcusd',
#   'time': 1388534400000,
#   'open': 730.24,
#   'close': 754.22,
#   'high': 757.0,
#   'low': 730.24,
#   'volume': 5883.99695487001},
#  {'symbol': 'btcusd',
#   'time': 1388620800000,
#   'open': 751.88,
#   'close': 784.34,
#   'high': 800.0,
#   'low': 742.52,
#   'volume': 9584.91453353008},
#  {'symbol': 'btcusd',
#   'time': 1388707200000,
#   'open': 784.12,
#   'close': 807.0,
#   'high': 818.99,
#   'low': 768.0,
#   'volume': 10253.8877436401},
#  {'symbol': 'btcusd',
#   'time': 1388793600000,
#   'open': 808.5,
#   'close': 829.0,
#   'high': 830.4,
#   'low': 791.04,
#   'volume': 10768.5978873301},
#  {'symbol': 'btcusd',
#   'time': 1388880000000,
#   'open': 829.9,
#   'close': 905.36,
#   'high': 939.8,
#   'low': 825.0,
#   'volume': 18946.6570916099},
#  {'symbol': 'btcusd',
#   'time': 1388966400000,
#   'open': 905.0,
#   'close': 919.24,
#   'high': 995.0,
#   'low': 875.181,
#   'volume': 21038.6254868698},
#  {'symbol': 'btcusd',
#   'time': 1389052800000,
#   'open': 915.7,
#   'close': 781.0,
#   'high': 943.15,
#   'low': 781.0,
#   'volume': 25356.8406498093},
#  {'symbol': 'btcusd',
#   'time': 1389139200000,
#   'open': 785.01,
#   'close': 824.89,
#   'high': 849.0,
#   'low': 765.0,
#   'volume': 20372.53172769},
#  {'symbol': 'btcusd',
#   'time': 1389225600000,
#   'open': 824.89,
#   'close': 826.2,
#   'high': 846.35,
#   'low': 779.99,
#   'volume': 15871.6025231103},
#  {'symbol': 'btcusd',
#   'time': 1389312000000,
#   'open': 825.5,
#   'close': 853.02,
#   'high': 860.64,
#   'low': 799.98,
#   'volume': 8011.79336830005},
#  {'symbol': 'btcusd',
#   'time': 1389398400000,
#   'open': 850.0,
#   'close': 896.59,
#   'high': 915.0,
#   'low': 848.0,
#   'volume': 10520.5960713802},
#  {'symbol': 'btcusd',
#   'time': 1389484800000,
#   'open': 898.5,
#   'close': 842.1,
#   'high': 906.0,
#   'low': 824.45143,
#   'volume': 10376.8434369101},
#  {'symbol': 'btcusd',
#   'time': 1389571200000,
#   'open': 842.01,
#   'close': 824.5,
#   'high': 844.68,
#   'low': 784.0,
#   'volume': 14308.7087051802},
#  {'symbol': 'btcusd',
#   'time': 1389657600000,
#   'open': 823.17,
#   'close': 816.0,
#   'high': 836.99,
#   'low': 802.3,
#   'volume': 4816.78362108003},
#  {'symbol': 'btcusd',
#   'time': 1389744000000,
#   'open': 816.0,
#   'close': 842.111,
#   'high': 850.25,
#   'low': 811.25,
#   'volume': 7238.15698086007},
#  {'symbol': 'btcusd',
#   'time': 1389830400000,
#   'open': 842.101,
#   'close': 812.48,
#   'high': 847.68,
#   'low': 812.48,
#   'volume': 3686.64958124},
#  {'symbol': 'btcusd',
#   'time': 1389916800000,
#   'open': 812.48,
#   'close': 800.0,
#   'high': 820.22,
#   'low': 765.03,
#   'volume': 11514.7178664003},
#  {'symbol': 'btcusd',
#   'time': 1390003200000,
#   'open': 798.99,
#   'close': 811.22,
#   'high': 820.0,
#   'low': 794.93,
#   'volume': 3987.64776987002},
#  {'symbol': 'btcusd',
#   'time': 1390089600000,
#   'open': 811.2,
#   'close': 841.11,
#   'high': 842.0,
#   'low': 794.41,
#   'volume': 6661.72551215013},
#  {'symbol': 'btcusd',
#   'time': 1390176000000,
#   'open': 842.07,
#   'close': 827.11,
#   'high': 844.99,
#   'low': 815.01,
#   'volume': 5520.23730462005},
#  {'symbol': 'btcusd',
#   'time': 1390262400000,
#   'open': 826.02,
#   'close': 824.34,
#   'high': 834.17,
#   'low': 813.6,
#   'volume': 2891.50023991},
#  {'symbol': 'btcusd',
#   'time': 1390348800000,
#   'open': 824.89,
#   'close': 818.0,
#   'high': 826.5,
#   'low': 803.1,
#   'volume': 2938.54753894001},
#  {'symbol': 'btcusd',
#   'time': 1390435200000,
#   'open': 817.99,
#   'close': 811.01,
#   'high': 823.0,
#   'low': 802.52,
#   'volume': 2838.97961165},
#  {'symbol': 'btcusd',
#   'time': 1390521600000,
#   'open': 811.01,
#   'close': 778.0,
#   'high': 812.7689,
#   'low': 767.23,
#   'volume': 11262.9423914602},
#  {'symbol': 'btcusd',
#   'time': 1390608000000,
#   'open': 778.13,
#   'close': 805.4,
#   'high': 817.0,
#   'low': 774.38,
#   'volume': 4713.79803381002},
#  {'symbol': 'btcusd',
#   'time': 1390694400000,
#   'open': 806.81,
#   'close': 815.0,
#   'high': 836.7318,
#   'low': 794.64,
#   'volume': 7513.57053368004},
#  {'symbol': 'btcusd',
#   'time': 1390780800000,
#   'open': 815.0,
#   'close': 750.0,
#   'high': 824.9999,
#   'low': 726.5,
#   'volume': 15629.6818693602},
#  {'symbol': 'btcusd',
#   'time': 1390867200000,
#   'open': 748.123,
#   'close': 784.0001,
#   'high': 814.5,
#   'low': 741.214,
#   'volume': 13647.5002643502},
#  {'symbol': 'btcusd',
#   'time': 1390953600000,
#   'open': 785.0,
#   'close': 791.56,
#   'high': 805.0,
#   'low': 781.4417,
#   'volume': 3865.88167876003},
#  {'symbol': 'btcusd',
#   'time': 1391040000000,
#   'open': 792.69,
#   'close': 801.5,
#   'high': 812.65489,
#   'low': 770.0,
#   'volume': 8205.38234448006},
#  {'symbol': 'btcusd',
#   'time': 1391126400000,
#   'open': 799.5,
#   'close': 803.5,
#   'high': 809.6746,
#   'low': 793.0,
#   'volume': 3912.0445727},
#  {'symbol': 'btcusd',
#   'time': 1391212800000,
#   'open': 803.58,
#   'close': 812.5211,
#   'high': 829.0,
#   'low': 801.0,
#   'volume': 4537.3743903},
#  {'symbol': 'btcusd',
#   'time': 1391299200000,
#   'open': 815.52,
#   'close': 814.222,
#   'high': 827.2,
#   'low': 811.0,
#   'volume': 3149.53715899001},
#  {'symbol': 'btcusd',
#   'time': 1391385600000,
#   'open': 814.222,
#   'close': 806.01,
#   'high': 815.2,
#   'low': 798.5,
#   'volume': 3446.69515272},
#  {'symbol': 'btcusd',
#   'time': 1391472000000,
#   'open': 806.01,
#   'close': 802.69,
#   'high': 814.4,
#   'low': 795.2,
#   'volume': 3363.63331922},
#  {'symbol': 'btcusd',
#   'time': 1391558400000,
#   'open': 800.0,
#   'close': 778.03,
#   'high': 807.48,
#   'low': 777.85,
#   'volume': 5215.28016818002},
#  {'symbol': 'btcusd',
#   'time': 1391644800000,
#   'open': 782.0,
#   'close': 763.11,
#   'high': 829.0,
#   'low': 678.03,
#   'volume': 21114.51912813},
#  {'symbol': 'btcusd',
#   'time': 1391731200000,
#   'open': 763.99,
#   'close': 702.0,
#   'high': 764.0,
#   'low': 620.0,
#   'volume': 42788.4246752395},
#  {'symbol': 'btcusd',
#   'time': 1391817600000,
#   'open': 702.0,
#   'close': 680.49,
#   'high': 723.97,
#   'low': 667.0,
#   'volume': 11122.2565993101},
#  {'symbol': 'btcusd',
#   'time': 1391904000000,
#   'open': 680.49,
#   'close': 689.0,
#   'high': 728.89934978,
#   'low': 666.53,
#   'volume': 12068.6993841901},
#  {'symbol': 'btcusd',
#   'time': 1391990400000,
#   'open': 686.11000001,
#   'close': 686.8313,
#   'high': 703.0,
#   'low': 200.0,
#   'volume': 41511.8031212395},
#  {'symbol': 'btcusd',
#   'time': 1392076800000,
#   'open': 686.0,
#   'close': 674.5,
#   'high': 721.35,
#   'low': 631.2,
#   'volume': 39535.0712279695},
#  {'symbol': 'btcusd',
#   'time': 1392163200000,
#   'open': 674.5,
#   'close': 652.05,
#   'high': 684.9,
#   'low': 642.0,
#   'volume': 12849.0181041001},
#  {'symbol': 'btcusd',
#   'time': 1392249600000,
#   'open': 652.01,
#   'close': 605.5,
#   'high': 658.9899,
#   'low': 603.43,
#   'volume': 17145.8786309402},
#  {'symbol': 'btcusd',
#   'time': 1392336000000,
#   'open': 605.6,
#   'close': 668.0,
#   'high': 710.0,
#   'low': 535.0,
#   'volume': 53681.7151358789},
#  {'symbol': 'btcusd',
#   'time': 1392422400000,
#   'open': 668.51,
#   'close': 651.92,
#   'high': 670.99,
#   'low': 633.3,
#   'volume': 10825.1136829301},
#  {'symbol': 'btcusd',
#   'time': 1392508800000,
#   'open': 654.78,
#   'close': 621.0,
#   'high': 670.9999,
#   'low': 585.0,
#   'volume': 16745.7315129901},
#  {'symbol': 'btcusd',
#   'time': 1392595200000,
#   'open': 622.19,
#   'close': 630.0,
#   'high': 664.0,
#   'low': 611.0,
#   'volume': 15689.9524364501},
#  {'symbol': 'btcusd',
#   'time': 1392681600000,
#   'open': 630.0,
#   'close': 627.95,
#   'high': 651.3,
#   'low': 611.304999,
#   'volume': 8466.24614979013},
#  {'symbol': 'btcusd',
#   'time': 1392768000000,
#   'open': 627.95,
#   'close': 621.75,
#   'high': 636.85,
#   'low': 617.89,
#   'volume': 4709.12040524005},
#  {'symbol': 'btcusd',
#   'time': 1392854400000,
#   'open': 624.0,
#   'close': 561.2,
# ...
#   'high': 245.57,
#   'low': 238.38,
#   'volume': 14351.3852635301},
#  {'symbol': 'btcusd',
#   'time': 1441843200000,
#   'open': 238.97,
#   'close': 239.49,
#   'high': 241.9,
#   'low': 237.01,
#   'volume': 10791.4928060403},
#  {'symbol': 'btcusd',
#   'time': 1441929600000,
#   'open': 239.4,
#   'close': 240.6,
#   'high': 242.89,
#   'low': 228.42,
#   'volume': 10243.4920350901},
#  {'symbol': 'btcusd',
#   'time': 1442016000000,
#   'open': 240.9,
#   'close': 235.77,
#   'high': 241.0,
#   'low': 235.33,
#   'volume': 9280.94291521014},
#  {'symbol': 'btcusd',
#   'time': 1442102400000,
#   'open': 235.86,
#   'close': 230.96,
#   'high': 236.85,
#   'low': 228.95,
#   'volume': 10215.5830291401},
#  {'symbol': 'btcusd',
#   'time': 1442188800000,
#   'open': 231.11,
#   'close': 230.89,
#   'high': 233.9,
#   'low': 228.4,
#   'volume': 9416.99072288005},
#  {'symbol': 'btcusd',
#   'time': 1442275200000,
#   'open': 231.07,
#   'close': 230.93,
#   'high': 232.93,
#   'low': 227.33,
#   'volume': 7621.52812507004},
#  {'symbol': 'btcusd',
#   'time': 1442361600000,
#   'open': 230.91,
#   'close': 228.99,
#   'high': 232.12,
#   'low': 227.38,
#   'volume': 8185.35355617014},
#  {'symbol': 'btcusd',
#   'time': 1442448000000,
#   'open': 228.99,
#   'close': 233.61,
#   'high': 235.94,
#   'low': 228.99,
#   'volume': 12037.7899456201},
#  {'symbol': 'btcusd',
#   'time': 1442534400000,
#   'open': 233.65,
#   'close': 228.34,
#   'high': 236.26,
#   'low': 227.0,
#   'volume': 9007.77255259012},
#  {'symbol': 'btcusd',
#   'time': 1442620800000,
#   'open': 233.79,
#   'close': 232.09,
#   'high': 234.19,
#   'low': 231.5,
#   'volume': 4329.15727342001},
#  {'symbol': 'btcusd',
#   'time': 1442707200000,
#   'open': 232.01,
#   'close': 232.12,
#   'high': 233.38,
#   'low': 231.4,
#   'volume': 3457.17417392999},
#  {'symbol': 'btcusd',
#   'time': 1442793600000,
#   'open': 232.11,
#   'close': 227.22,
#   'high': 232.97,
#   'low': 226.38,
#   'volume': 9274.07985298007},
#  {'symbol': 'btcusd',
#   'time': 1442880000000,
#   'open': 227.25,
#   'close': 231.11,
#   'high': 233.95,
#   'low': 224.25,
#   'volume': 18854.9366088299},
#  {'symbol': 'btcusd',
#   'time': 1442966400000,
#   'open': 231.43,
#   'close': 230.54,
#   'high': 233.0,
#   'low': 230.03,
#   'volume': 5720.27547465002},
#  {'symbol': 'btcusd',
#   'time': 1443052800000,
#   'open': 230.57,
#   'close': 234.65,
#   'high': 236.25,
#   'low': 230.54,
#   'volume': 15377.2409667202},
#  {'symbol': 'btcusd',
#   'time': 1443139200000,
#   'open': 234.65,
#   'close': 235.26,
#   'high': 237.7,
#   'low': 233.05,
#   'volume': 9861.42777709997},
#  {'symbol': 'btcusd',
#   'time': 1443225600000,
#   'open': 235.39,
#   'close': 234.63,
#   'high': 235.95,
#   'low': 233.75,
#   'volume': 4796.04811748002},
#  {'symbol': 'btcusd',
#   'time': 1443312000000,
#   'open': 234.63,
#   'close': 233.37,
#   'high': 234.78,
#   'low': 233.0,
#   'volume': 2592.00155383},
#  {'symbol': 'btcusd',
#   'time': 1443398400000,
#   'open': 233.37,
#   'close': 240.43,
#   'high': 241.44,
#   'low': 233.37,
#   'volume': 12488.2201599902},
#  {'symbol': 'btcusd',
#   'time': 1443484800000,
#   'open': 240.43,
#   'close': 236.8,
#   'high': 241.5,
#   'low': 236.61,
#   'volume': 9459.77890536007},
#  {'symbol': 'btcusd',
#   'time': 1443571200000,
#   'open': 236.9,
#   'close': 236.49,
#   'high': 238.78,
#   'low': 235.11,
#   'volume': 5152.91520089002},
#  {'symbol': 'btcusd',
#   'time': 1443657600000,
#   'open': 236.72,
#   'close': 238.48,
#   'high': 240.09,
#   'low': 236.19,
#   'volume': 6107.43096947003},
#  {'symbol': 'btcusd',
#   'time': 1443744000000,
#   'open': 238.25,
#   'close': 237.86,
#   'high': 240.0,
#   'low': 237.33,
#   'volume': 5607.98936459},
#  {'symbol': 'btcusd',
#   'time': 1443830400000,
#   'open': 237.84,
#   'close': 239.79,
#   'high': 241.11,
#   'low': 237.68,
#   'volume': 6221.09736250003},
#  {'symbol': 'btcusd',
#   'time': 1443916800000,
#   'open': 239.73,
#   'close': 239.5,
#   'high': 240.93,
#   'low': 239.29,
#   'volume': 2081.94241537},
#  {'symbol': 'btcusd',
#   'time': 1444003200000,
#   'open': 239.47,
#   'close': 242.0,
#   'high': 242.89,
#   'low': 236.24,
#   'volume': 12198.9370202802},
#  {'symbol': 'btcusd',
#   'time': 1444089600000,
#   'open': 242.01,
#   'close': 247.36,
#   'high': 249.01,
#   'low': 241.51,
#   'volume': 16277.3495449002},
#  {'symbol': 'btcusd',
#   'time': 1444176000000,
#   'open': 247.35,
#   'close': 244.0,
#   'high': 247.93,
#   'low': 243.5,
#   'volume': 8806.62652877009},
#  {'symbol': 'btcusd',
#   'time': 1444262400000,
#   'open': 244.0,
#   'close': 243.0,
#   'high': 245.65,
#   'low': 242.62,
#   'volume': 6046.70528353999},
#  {'symbol': 'btcusd',
#   'time': 1444348800000,
#   'open': 242.99,
#   'close': 244.82,
#   'high': 245.45,
#   'low': 242.63,
#   'volume': 3572.48926214999},
#  {'symbol': 'btcusd',
#   'time': 1444435200000,
#   'open': 244.93,
#   'close': 246.01,
#   'high': 246.41,
#   'low': 243.5,
#   'volume': 4196.52667741001},
#  {'symbol': 'btcusd',
#   'time': 1444521600000,
#   'open': 245.93,
#   'close': 247.99,
#   'high': 248.73,
#   'low': 243.75,
#   'volume': 4868.94170189005},
#  {'symbol': 'btcusd',
#   'time': 1444608000000,
#   'open': 247.92,
#   'close': 246.17,
#   'high': 248.45,
#   'low': 245.21,
#   'volume': 5203.50998203004},
#  {'symbol': 'btcusd',
#   'time': 1444694400000,
#   'open': 246.15,
#   'close': 251.25,
#   'high': 253.43,
#   'low': 244.0,
#   'volume': 16746.3196923102},
#  {'symbol': 'btcusd',
#   'time': 1444780800000,
#   'open': 251.08,
#   'close': 253.5,
#   'high': 255.95,
#   'low': 250.1,
#   'volume': 10143.2669366501},
#  {'symbol': 'btcusd',
#   'time': 1444867200000,
#   'open': 253.5,
#   'close': 255.19,
#   'high': 257.5,
#   'low': 253.44,
#   'volume': 10462.8704923201},
#  {'symbol': 'btcusd',
#   'time': 1444953600000,
#   'open': 255.19,
#   'close': 263.45,
#   'high': 267.83,
#   'low': 254.91,
#   'volume': 21966.84227808},
#  {'symbol': 'btcusd',
#   'time': 1445040000000,
#   'open': 263.47,
#   'close': 272.9,
#   'high': 275.19,
#   'low': 258.32,
#   'volume': 42840.6676771494},
#  {'symbol': 'btcusd',
#   'time': 1445126400000,
#   'open': 272.9,
#   'close': 265.01,
#   'high': 274.66,
#   'low': 263.3,
#   'volume': 15347.1930916302},
#  {'symbol': 'btcusd',
#   'time': 1445212800000,
#   'open': 265.29,
#   'close': 265.1,
#   'high': 268.28,
#   'low': 262.35,
#   'volume': 10903.4191689701},
#  {'symbol': 'btcusd',
#   'time': 1445299200000,
#   'open': 265.02,
#   'close': 270.97,
#   'high': 273.97,
#   'low': 264.39,
#   'volume': 14439.64408514},
#  {'symbol': 'btcusd',
#   'time': 1445385600000,
#   'open': 270.99,
#   'close': 267.8,
#   'high': 272.28,
#   'low': 264.1,
#   'volume': 10617.4462959401},
#  {'symbol': 'btcusd',
#   'time': 1445472000000,
#   'open': 267.99,
#   'close': 275.83,
#   'high': 279.97,
#   'low': 267.3,
#   'volume': 27240.7695845001},
#  {'symbol': 'btcusd',
#   'time': 1445558400000,
#   'open': 275.83,
#   'close': 279.21,
#   'high': 280.9,
#   'low': 275.15,
#   'volume': 15857.5633378301},
#  {'symbol': 'btcusd',
#   'time': 1445644800000,
#   'open': 279.04,
#   'close': 284.19,
#   'high': 284.47,
#   'low': 279.0,
#   'volume': 13934.5865672404},
#  {'symbol': 'btcusd',
#   'time': 1445731200000,
#   'open': 284.19,
#   'close': 284.79,
#   'high': 295.99,
#   'low': 281.2,
#   'volume': 40017.6507968993},
#  {'symbol': 'btcusd',
#   'time': 1445817600000,
#   'open': 284.7,
#   'close': 287.22,
#   'high': 287.92,
#   'low': 282.25,
#   'volume': 17157.5562752399},
#  {'symbol': 'btcusd',
#   'time': 1445904000000,
#   'open': 287.22,
#   'close': 295.29,
#   'high': 298.86,
#   'low': 286.71,
#   'volume': 26822.8422907294},
#  {'symbol': 'btcusd',
#   'time': 1445990400000,
#   'open': 295.29,
#   'close': 304.5,
#   'high': 307.99,
#   'low': 295.29,
#   'volume': 35610.6397048694},
#  {'symbol': 'btcusd',
#   'time': 1446076800000,
#   'open': 304.5,
#   'close': 314.88,
#   'high': 321.53,
#   'low': 301.5,
#   'volume': 51213.84331228},
#  {'symbol': 'btcusd',
#   'time': 1446163200000,
#   'open': 314.23,
#   'close': 328.19,
#   'high': 336.0,
#   'low': 313.82,
#   'volume': 62862.2379375905},
#  {'symbol': 'btcusd',
#   'time': 1446249600000,
#   'open': 328.2,
#   'close': 316.0,
#   'high': 335.87,
#   'low': 307.2,
#   'volume': 42942.3117877901},
#  {'symbol': 'btcusd',
#   'time': 1446336000000,
#   'open': 316.0,
#   'close': 330.23,
#   'high': 333.49,
#   'low': 313.6,
#   'volume': 25673.0870176499},
#  {'symbol': 'btcusd',
#   'time': 1446422400000,
#   'open': 330.23,
#   'close': 365.33,
#   'high': 373.12,
#   'low': 326.8,
#   'volume': 71218.1479877504},
#  {'symbol': 'btcusd',
#   'time': 1446508800000,
#   'open': 365.08,
#   'close': 405.0,
#   'high': 423.88,
#   'low': 361.11,
#   'volume': 171811.474232742},
#  {'symbol': 'btcusd',
#   'time': 1446595200000,
#   'open': 404.98,
#   'close': 409.24,
#   'high': 504.0,
#   'low': 366.66,
#   'volume': 274470.238233948},
#  {'symbol': 'btcusd',
#   'time': 1446681600000,
#   'open': 409.23,
#   'close': 387.14,
#   'high': 449.95,
#   'low': 370.0,
#   'volume': 157932.047982652},
#  {'symbol': 'btcusd',
#   'time': 1446768000000,
#   'open': 387.93,
#   'close': 375.56,
#   'high': 396.78,
#   'low': 351.2,
#   'volume': 106656.205296153},
#  {'symbol': 'btcusd',
#   'time': 1446854400000,
#   'open': 375.56,
#   'close': 384.99,
#   'high': 392.23,
#   'low': 371.32,
#   'volume': 34416.7134629302},
#  {'symbol': 'btcusd',
#   'time': 1446940800000,
#   'open': 384.28,
#   'close': 374.1,
#   'high': 390.33,
#   'low': 365.56,
#   'volume': 30831.9230109598},
#  {'symbol': 'btcusd',
#   'time': 1447027200000,
#   'open': 374.52,
#   'close': 381.1,
#   'high': 388.99,
#   'low': 360.0,
#   'volume': 38111.9548491391},
#  {'symbol': 'btcusd',
#   'time': 1447113600000,
#   'open': 381.1,
#   'close': 340.18,
#   'high': 383.4,
#   'low': 327.02,
#   'volume': 88482.2856964404},
#  {'symbol': 'btcusd',
#   'time': 1447200000000,
#   'open': 340.18,
#   'close': 314.45,
#   'high': 343.79,
#   'low': 300.28,
#   'volume': 117018.931485865},
#  {'symbol': 'btcusd',
#   'time': 1447286400000,
#   'open': 314.45,
#   'close': 336.84,
#   'high': 346.44,
#   'low': 314.14,
#   'volume': 57236.7552054516},
#  {'symbol': 'btcusd',
#   'time': 1447372800000,
#   'open': 336.86,
#   'close': 338.53,
#   'high': 343.75,
#   'low': 326.22,
#   'volume': 29935.630229709},
#  {'symbol': 'btcusd',
#   'time': 1447459200000,
#   'open': 338.54,
#   'close': 333.37,
#   'high': 340.72,
#   'low': 328.5,
#   'volume': 20324.6267692602},
#  {'symbol': 'btcusd',
#   'time': 1447545600000,
#   'open': 333.39,
#   'close': 320.52,
#   'high': 336.6,
#   'low': 315.0,
#   'volume': 31597.1678628498},
#  {'symbol': 'btcusd',
#   'time': 1447632000000,
#   'open': 320.8,
#   'close': 332.1,
#   'high': 335.0,
#   'low': 315.2,
#   'volume': 25747.0142364501},
#  {'symbol': 'btcusd',
#   'time': 1447718400000,
#   'open': 332.16,
#   'close': 336.29,
#   'high': 342.5,
#   'low': 331.05,
#   'volume': 27167.9770198597},
#  {'symbol': 'btcusd',
#   'time': 1447804800000,
#   'open': 336.29,
#   'close': 335.94,
#   'high': 338.99,
#   'low': 327.91,
#   'volume': 15625.5383197102},
#  {'symbol': 'btcusd',
#   'time': 1447891200000,
#   'open': 335.83,
#   'close': 326.5,
#   'high': 336.57,
#   'low': 324.02,
#   'volume': 18932.5528605301},
#  {'symbol': 'btcusd',
#   'time': 1447977600000,
#   'open': 326.49,
#   'close': 322.2,
#   'high': 326.77,
#   'low': 309.46,
#   'volume': 30160.0102475389},
#  {'symbol': 'btcusd',
#   'time': 1448064000000,
#   'open': 322.29,
#   'close': 327.84,
#   'high': 329.35,
#   'low': 318.95,
#   'volume': 10478.8557161701},
#  {'symbol': 'btcusd',
#   'time': 1448150400000,
#   'open': 327.84,
#   'close': 324.66,
#   'high': 327.85,
#   'low': 320.36,
#   'volume': 7051.90999034007},
#  {'symbol': 'btcusd',
#   'time': 1448236800000,
#   'open': 324.66,
#   'close': 323.63,
#   'high': 327.5,
#   'low': 320.9,
#   'volume': 7775.67515741017},
#  {'symbol': 'btcusd',
#   'time': 1448323200000,
#   'open': 323.65,
#   'close': 320.1,
#   'high': 323.77,
#   'low': 315.55,
#   'volume': 9618.01049005007},
#  {'symbol': 'btcusd',
#   'time': 1448409600000,
#   'open': 320.49,
#   'close': 329.85,
#   'high': 332.43,
#   'low': 316.02,
#   'volume': 20618.16569952},
#  {'symbol': 'btcusd',
#   'time': 1448496000000,
#   'open': 329.85,
#   'close': 354.0,
#   'high': 369.9,
#   'low': 329.35,
#   'volume': 81494.1298063883},
#  {'symbol': 'btcusd',
#   'time': 1448582400000,
#   'open': 354.0,
#   'close': 358.9,
#   'high': 367.0,
#   'low': 348.18,
#   'volume': 34902.8588615199},
#  {'symbol': 'btcusd',
#   'time': 1448668800000,
#   'open': 359.0,
#   'close': 358.6,
#   'high': 362.44,
#   'low': 351.0,
#   'volume': 19427.6777883994},
#  {'symbol': 'btcusd',
#   'time': 1448755200000,
#   'open': 358.54,
#   'close': 373.89,
#   'high': 376.0,
#   'low': 355.17,
#   'volume': 25800.6895178296},
#  {'symbol': 'btcusd',
#   'time': 1448841600000,
#   'open': 373.84,
#   'close': 376.88,
#   'high': 384.99,
#   'low': 368.11,
#   'volume': 47495.8553783626},
#  {'symbol': 'btcusd',
#   'time': 1448928000000,
#   'open': 376.89,
#   'close': 362.59,
#   'high': 379.99,
#   'low': 353.1,
#   'volume': 44101.9174780196},
#  {'symbol': 'btcusd',
#   'time': 1449014400000,
#   'open': 362.59,
#   'close': 359.12,
#   'high': 363.22,
#   'low': 346.13,
#   'volume': 31554.7711214792},
#  {'symbol': 'btcusd',
#   'time': 1449100800000,
#   'open': 359.12,
#   'close': 360.53,
#   'high': 371.5,
#   'low': 352.25,
#   'volume': 27383.7998960896},
#  {'symbol': 'btcusd',
#   'time': 1449187200000,
#   'open': 360.62,
#   'close': 363.17,
#   'high': 364.4,
#   'low': 354.31,
#   'volume': 14651.48749597},
#  {'symbol': 'btcusd',
#   'time': 1449273600000,
#   'open': 363.04,
#   'close': 389.79,
#   'high': 395.0,
#   'low': 362.08,
#   'volume': 46142.2954009557},
#  {'symbol': 'btcusd',
#   'time': 1449360000000,
#   'open': 390.01,
#   'close': 390.6,
#   'high': 407.57,
#   'low': 386.01,
#   'volume': 60599.9246639897},
#  {'symbol': 'btcusd',
#   'time': 1449446400000,
#   'open': 390.88,
#   'close': 396.7,
#   'high': 404.24,
#   'low': 384.53,
#   'volume': 33608.0116661191},
#  {'symbol': 'btcusd',
#   'time': 1449532800000,
#   'open': 397.0,
#   'close': 422.0,
#   'high': 422.39,
#   'low': 388.37,
#   'volume': 33197.6232290996},
#  {'symbol': 'btcusd',
#   'time': 1449619200000,
#   'open': 422.0,
#   'close': 418.73,
#   'high': 426.59,
#   'low': 405.0,
#   'volume': 52055.3207085403},
#  {'symbol': 'btcusd',
#   'time': 1449705600000,
#   'open': 418.86,
#   'close': 414.94,
#   'high': 421.82,
#   'low': 411.09,
#   'volume': 21325.4436757199},
#  {'symbol': 'btcusd',
#   'time': 1449792000000,
#   'open': 414.88,
#   'close': 457.0,
#   'high': 458.99,
#   'low': 414.8,
#   'volume': 75656.53043328},
#  {'symbol': 'btcusd',
#   'time': 1449878400000,
#   'open': 456.32,
#   'close': 435.61,
#   'high': 475.04,
#   'low': 402.5,
#   'volume': 104706.951044479},
#  {'symbol': 'btcusd',
#   'time': 1449964800000,
#   'open': 435.61,
#   'close': 433.36,
#   'high': 443.92,
#   'low': 415.24,
#   'volume': 33630.9154140993},
#  {'symbol': 'btcusd',
#   'time': 1450051200000,
#   'open': 432.91,
#   'close': 442.59,
#   'high': 450.0,
#   'low': 427.3,
#   'volume': 27298.3671313097},
#  {'symbol': 'btcusd',
#   'time': 1450137600000,
#   'open': 442.55,
#   'close': 466.01,
#   'high': 467.29,
#   'low': 442.51,
#   'volume': 41307.2211420201},
#  {'symbol': 'btcusd',
#   'time': 1450224000000,
#   'open': 466.43,
#   'close': 454.94,
#   'high': 469.99,
#   'low': 440.0,
#   'volume': 67047.01540226},
#  {'symbol': 'btcusd',
#   'time': 1450310400000,
#   'open': 454.94,
#   'close': 455.57,
#   'high': 458.56,
#   'low': 446.21,
#   'volume': 17868.8555859299},
#  {'symbol': 'btcusd',
#   'time': 1450396800000,
#   'open': 455.71,
#   'close': 463.52,
#   'high': 466.6,
#   'low': 450.1,
#   'volume': 27050.4515447595},
#  {'symbol': 'btcusd',
#   'time': 1450483200000,
#   'open': 463.51,
#   'close': 462.44,
#   'high': 467.0,
#   'low': 452.0,
#   'volume': 21223.5797220801},
#  {'symbol': 'btcusd',
#   'time': 1450569600000,
#   'open': 462.45,
#   'close': 442.62,
#   'high': 462.78,
#   'low': 431.5,
#   'volume': 46323.16552625},
#  {'symbol': 'btcusd',
#   'time': 1450656000000,
#   'open': 442.62,
#   'close': 437.52,
#   'high': 447.45,
#   'low': 424.37,
#   'volume': 43203.8050521996},
#  {'symbol': 'btcusd',
#   'time': 1450742400000,
#   'open': 437.81,
#   'close': 435.65,
#   'high': 443.64,
#   'low': 433.0,
#   'volume': 18516.1208485401},
#  {'symbol': 'btcusd',
#   'time': 1450828800000,
#   'open': 435.05,
#   'close': 442.62,
#   'high': 445.76,
#   'low': 433.62,
#   'volume': 16464.7867774501},
#  {'symbol': 'btcusd',
#   'time': 1450915200000,
#   'open': 442.62,
#   'close': 456.13,
#   'high': 459.1,
#   'low': 442.45,
#   'volume': 19865.73831943},
#  {'symbol': 'btcusd',
#   'time': 1451001600000,
#   'open': 456.02,
#   'close': 455.47,
#   'high': 460.0,
#   'low': 445.0,
#   'volume': 15176.7280263202},
#  ...]

# %%
df = pd.io.json.json_normalize(json_data)
df.head()
# Out:
# <ipython-input-33-3d0a9fa7477a>:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df = pd.io.json.json_normalize(json_data)
#    symbol           time        open       close       high        low  \
# 0  btcusd  1364688000000   92.500000   93.033000   93.74999   91.00000
# 1  btcusd  1364774400000   93.250000  103.999000  105.90000   92.49999
# 2  btcusd  1364860800000  104.000000  118.229354  118.38670   99.00000
# 3  btcusd  1364947200000  117.958261  134.700000  146.88000  101.51088
# 4  btcusd  1365033600000  134.716560  132.899000  143.00000  119.00000
#
#          volume
# 0   3083.079791
# 1   5224.401313
# 2   8376.527478
# 3  12996.245072
# 4   6981.668305

# %% [markdown]
# The `json_normalize` function used to be in the `pd.io.json module`, but has moved to the top-level `pd` module for simplicity. The `FutureWarning` about deprecation above tells us that.

# %%
df = pd.json_normalize(json_data)
df.head()
# Out:
#    symbol           time        open       close       high        low  \
# 0  btcusd  1364688000000   92.500000   93.033000   93.74999   91.00000
# 1  btcusd  1364774400000   93.250000  103.999000  105.90000   92.49999
# 2  btcusd  1364860800000  104.000000  118.229354  118.38670   99.00000
# 3  btcusd  1364947200000  117.958261  134.700000  146.88000  101.51088
# 4  btcusd  1365033600000  134.716560  132.899000  143.00000  119.00000
#
#          volume
# 0   3083.079791
# 1   5224.401313
# 2   8376.527478
# 3  12996.245072
# 4   6981.668305

# %% [markdown]
# ### Reading big data in chunks
# Sometimes we will be dealing with very large data files, like CSV files or other files that are in the 10s of GB. We can chunk through these files to manage memory. This is available for CSV, JSON, HDF, SAS, SQL, and Stata files.
#
# There are about 2700 lines in the bitcoin data, so we get 3 chunks with `chunksize=1000`.

# %%
for chunk in pd.read_csv('data/bitcoin_price.csv', chunksize=1000):
    print(chunk.head())
# Out:
#    symbol           time        open       close       high        low  \
# 0  btcusd  1364688000000   92.500000   93.033000   93.74999   91.00000
# 1  btcusd  1364774400000   93.250000  103.999000  105.90000   92.49999
# 2  btcusd  1364860800000  104.000000  118.229354  118.38670   99.00000
# 3  btcusd  1364947200000  117.958261  134.700000  146.88000  101.51088
# 4  btcusd  1365033600000  134.716560  132.899000  143.00000  119.00000
#
#          volume
# 0   3083.079791
# 1   5224.401313
# 2   8376.527478
# 3  12996.245072
# 4   6981.668305
#       symbol           time    open   close    high     low        volume
# 1000  btcusd  1451088000000  455.30  416.51  460.05  405.50  96491.880172
# 1001  btcusd  1451174400000  416.35  422.32  424.89  407.00  27798.815511
# 1002  btcusd  1451260800000  421.82  420.24  429.00  417.01  24284.330077
# 1003  btcusd  1451347200000  420.11  431.79  433.55  418.01  22073.563200
# 1004  btcusd  1451433600000  431.77  423.55  434.00  420.00  22247.596458
#       symbol           time    open   close         high     low        volume
# 2000  btcusd  1538092800000  6691.4  6635.2  6826.419665  6541.9  27892.966656
# 2001  btcusd  1538179200000  6635.1  6597.3  6635.100000  6454.2  17305.626896
# 2002  btcusd  1538265600000  6597.2  6622.4  6662.800000  6529.6   8494.153672
# 2003  btcusd  1538352000000  6622.3  6601.9  6660.000000  6500.0  10358.011597
# 2004  btcusd  1538438400000  6602.0  6527.5  6644.700000  6467.9  12037.347954

# %% [markdown]
# # Basic Exploratory Data Analysis (EDA) and Plotting with Pandas
#
# ## Numeric EDA

# %% [markdown]
# There are a few useful EDA functions in pandas to use often:

# %%
btc_df = pd.read_csv('data/bitcoin_price.csv')
btc_df.describe()
# Out:
#                time          open         close          high           low  \
# count  2.793000e+03   2793.000000   2793.000000   2793.000000   2793.000000
# mean   1.485643e+12   3867.990614   3874.250920   3981.107823   3742.840459
# std    6.993213e+10   4275.693859   4283.044674   4407.995959   4122.644430
# min    1.364688e+12     66.120000     66.120000     73.260000      0.010000
# 25%    1.424995e+12    404.980000    407.270000    415.800000    388.011000
# 50%    1.485907e+12   1003.800000   1006.600000   1033.000000    960.100000
# 75%    1.546214e+12   7367.100000   7369.831761   7551.600000   7200.000000
# max    1.606522e+12  19209.000000  19210.000000  19891.000000  18622.000000
#
#               volume
# count    2793.000000
# mean    20916.237912
# std     23815.877524
# min       399.440586
# 25%      6072.663816
# 50%     12773.963029
# 75%     26917.867083
# max    274470.238234

# %%
btc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2793 entries, 0 to 2792
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   symbol  2793 non-null   object
#  1   time    2793 non-null   int64
#  2   open    2793 non-null   float64
#  3   close   2793 non-null   float64
#  4   high    2793 non-null   float64
#  5   low     2793 non-null   float64
#  6   volume  2793 non-null   float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 152.9+ KB

# %% [markdown]
# It's a little annoying to subtract the missing values from the total number of values, so we can use `.isna()` with `.sum()`:

# %%
btc_df.isna().sum()
# Out:
# symbol    0
# time      0
# open      0
# close     0
# high      0
# low       0
# volume    0
# dtype: int64

# %% [markdown]
# We can find the number of rows and columns like so:

# %%
btc_df.shape
# Out:
# (2793, 7)

# %% [markdown]
# We might also want to see the datatypes of our DataFrame.

# %%
btc_df.dtypes
# Out:
# symbol     object
# time        int64
# open      float64
# close     float64
# high      float64
# low       float64
# volume    float64
# dtype: object

# %% [markdown]
# We can also get some other stats, such as the median and mode:

# %%
btc_df.median()
# Out:
# time      1.485907e+12
# open      1.003800e+03
# close     1.006600e+03
# high      1.033000e+03
# low       9.601000e+02
# volume    1.277396e+04
# dtype: float64

# %%
btc_df['symbol'].mode()
# Out:
# 0    btcusd
# dtype: object

# %% [markdown]
# It can also be useful to look at unique values and value counts. We'll look at some unique values and counts from the tracks from our chinook database.

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite:///data/chinook.db')
connection = engine.connect()
df = pd.read_sql_table('tracks', connection)

# %%
df.head()
# Out:
#    TrackId                                     Name  AlbumId  MediaTypeId  \
# 0        1  For Those About To Rock (We Salute You)        1            1
# 1        2                        Balls to the Wall        2            2
# 2        3                          Fast As a Shark        3            2
# 3        4                        Restless and Wild        3            2
# 4        5                     Princess of the Dawn        3            2
#
#    GenreId                                           Composer  Milliseconds  \
# 0        1          Angus Young, Malcolm Young, Brian Johnson        343719
# 1        1                                               None        342562
# 2        1  F. Baltes, S. Kaufman, U. Dirkscneider & W. Ho...        230619
# 3        1  F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. D...        252051
# 4        1                         Deaffy & R.A. Smith-Diesel        375418
#
#       Bytes  UnitPrice
# 0  11170334       0.99
# 1   5510424       0.99
# 2   3990994       0.99
# 3   4331779       0.99
# 4   6290521       0.99

# %%
df['UnitPrice'].unique()
# Out:
# array([0.99, 1.99])

# %%
df['UnitPrice'].value_counts()
# Out:
# 0.99    3290
# 1.99     213
# Name: UnitPrice, dtype: int64

# %% [markdown]
# ## Selecting Columns and Rows, and Filtering

# %%
btc_df = pd.read_csv('data/bitcoin_price.csv', index_col='time')
btc_df.head()
# Out:
#                symbol        open       close       high        low  \
# time
# 1364688000000  btcusd   92.500000   93.033000   93.74999   91.00000
# 1364774400000  btcusd   93.250000  103.999000  105.90000   92.49999
# 1364860800000  btcusd  104.000000  118.229354  118.38670   99.00000
# 1364947200000  btcusd  117.958261  134.700000  146.88000  101.51088
# 1365033600000  btcusd  134.716560  132.899000  143.00000  119.00000
#
#                      volume
# time
# 1364688000000   3083.079791
# 1364774400000   5224.401313
# 1364860800000   8376.527478
# 1364947200000  12996.245072
# 1365033600000   6981.668305

# %% [markdown]
# We can view the index and columns like so.

# %%
print(btc_df.columns)
print(btc_df.index)
# Out:
# Index(['symbol', 'open', 'close', 'high', 'low', 'volume'], dtype='object')
# Int64Index([1364688000000, 1364774400000, 1364860800000, 1364947200000,
#             1365033600000, 1365120000000, 1365206400000, 1365292800000,
#             1365379200000, 1365465600000,
#             ...
#             1605744000000, 1605830400000, 1605916800000, 1606003200000,
#             1606089600000, 1606176000000, 1606262400000, 1606348800000,
#             1606435200000, 1606521600000],
#            dtype='int64', name='time', length=2793)

# %% [markdown]
# To select a column, we use square brackets with the column name. To select a row, we can use square brackets with the index value for that row.

# %%
# select a column
btc_df['volume']
# Out:
# time
# 1364688000000     3083.079791
# 1364774400000     5224.401313
# 1364860800000     8376.527478
# 1364947200000    12996.245072
# 1365033600000     6981.668305
#                      ...
# 1606176000000    14937.354569
# 1606262400000    13477.604832
# 1606348800000    34343.561464
# 1606435200000    11217.912098
# 1606521600000     3535.952749
# Name: volume, Length: 2793, dtype: float64

# %%
# select the first row
btc_df.loc[1364688000000]
# Out:
# symbol     btcusd
# open         92.5
# close      93.033
# high        93.75
# low            91
# volume    3083.08
# Name: 1364688000000, dtype: object

# %%
# select a row and column
btc_df.loc[1364688000000, 'volume']
# Out:
# 3083.07979075

# %%
# select a row with the number of the row (first, second, etc), not the index
btc_df.iloc[0]
# Out:
# symbol     btcusd
# open         92.5
# close      93.033
# high        93.75
# low            91
# volume    3083.08
# Name: 1364688000000, dtype: object

# %%
# select volume from the first row
btc_df.iloc[0, 5]
# Out:
# 3083.07979075

# %% [markdown]
# We can also filter DataFrames much like the WHERE statement in SQL. For example, all rows with a volume above 3000 can be obtained like so:

# %%
btc_df[btc_df['volume'] > 3000]
# Out:
#       symbol           time          open         close         high  \
# 0     btcusd  1364688000000     92.500000     93.033000     93.74999
# 1     btcusd  1364774400000     93.250000    103.999000    105.90000
# 2     btcusd  1364860800000    104.000000    118.229354    118.38670
# 3     btcusd  1364947200000    117.958261    134.700000    146.88000
# 4     btcusd  1365033600000    134.716560    132.899000    143.00000
# ...      ...            ...           ...           ...          ...
# 2788  btcusd  1606176000000  18364.000000  19131.000000  19400.00000
# 2789  btcusd  1606262400000  19133.654712  18727.000000  19497.00000
# 2790  btcusd  1606348800000  18726.475677  17211.695801  18908.00000
# 2791  btcusd  1606435200000  17213.000000  17171.000000  17531.00000
# 2792  btcusd  1606521600000  17171.000000  17686.840768  17705.00000
#
#               low        volume
# 0        91.00000   3083.079791
# 1        92.49999   5224.401313
# 2        99.00000   8376.527478
# 3       101.51088  12996.245072
# 4       119.00000   6981.668305
# ...           ...           ...
# 2788  18130.00000  14937.354569
# 2789  18500.00000  13477.604832
# 2790  16317.00000  34343.561464
# 2791  16501.00000  11217.912098
# 2792  16925.00000   3535.952749
#
# [2573 rows x 7 columns]

# %% [markdown]
# The inner part of the statement returns a boolean Pandas Series:

# %%
btc_df['volume'] > 3000
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 2788    True
# 2789    True
# 2790    True
# 2791    True
# 2792    True
# Name: volume, Length: 2793, dtype: bool

# %%
type(btc_df['volume'] > 3000)
# Out:
# pandas.core.series.Series

# %% [markdown]
# A few other methods for filtering are useful: `isna`, `isin()` and `.str.contains()`.

# %%
df = pd.DataFrame(data={'text': ['A good dog!', 'A bad dog.', 'This cat is good.']})
df[df['text'].str.contains('good')]
# Out:
#                 text
# 0        A good dog!
# 2  This cat is good.

# %% [markdown]
# We can negate a filter with `~`.

# %%
df[~df['text'].str.contains('good')]
# Out:
#          text
# 1  A bad dog.

# %% [markdown]
# For finding if a row contains a value in a set or list, we can use `isin`:

# %%
df = pd.DataFrame(data={'City': ['Los Angeles', 'San Francisco', 'New York', 'Omaha', 'Atlantis'],
                        'State': ['CA', 'CA', 'NY', 'NE', pd.NA]})
df[df['State'].isin(['CA', 'NY'])]
# Out:
#             City State
# 0    Los Angeles    CA
# 1  San Francisco    CA
# 2       New York    NY

# %%
df[df['State'].isna()]
# Out:
#        City State
# 4  Atlantis  <NA>

# %%
df[df['State'].notnull()]
# Out:
#             City State
# 0    Los Angeles    CA
# 1  San Francisco    CA
# 2       New York    NY
# 3          Omaha    NE

# %% [markdown]
# Finally, we can combine filtering statements with & for "and" and | for "or". You should encapsulate each condition in parentheses.

# %%
df[(df['State'] == 'CA') & (df['City'] == 'Los Angeles')]
# Out:
#           City State
# 0  Los Angeles    CA

# %% [markdown]
# ## Plotting
# Pandas can easily plot data, natively. Let's first plot a histogram of song lengths.
#
# If plotting in IPython, simply running `%matplotlib` allows you to continue to run code after you've plotted something.
#
# `%matplotlib inline` in a Jupyter Notebook shows the plots automatically, but they are not interactive.

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite:///data/chinook.db')
connection = engine.connect()
df = pd.read_sql_table('tracks', connection)

# %%
_ = df['Milliseconds'].hist()

# %% [markdown]
# A handy trick is to use `value_counts` with a barplot:

# %%
_ = df['GenreId'].value_counts().plot.bar()

# %% [markdown]
# If we have a timeseries, pandas can plot that very well too. It helps to have our index to be a time value.

# %%
btc_df = pd.read_csv('data/bitcoin_price.csv', index_col='time')

# %%
btc_df.drop(['volume', 'low'], axis=1).plot(logy=True)
# Out:
# <AxesSubplot:xlabel='time'>

# %% [markdown]
# # Preparing and Cleaning Data with Pandas

# %% [markdown]
# Setting and Resetting the Index
#
# Math (adding, subtracting, etc)
#
# Converting datatypes
#
# Timestamps -- conversions

# %% [markdown]
# We can drop columns with .drop():

# %%
btc_df.drop('volume', axis=1)
# Out:
#                symbol          open         close         high          low
# time
# 1364688000000  btcusd     92.500000     93.033000     93.74999     91.00000
# 1364774400000  btcusd     93.250000    103.999000    105.90000     92.49999
# 1364860800000  btcusd    104.000000    118.229354    118.38670     99.00000
# 1364947200000  btcusd    117.958261    134.700000    146.88000    101.51088
# 1365033600000  btcusd    134.716560    132.899000    143.00000    119.00000
# ...               ...           ...           ...          ...          ...
# 1606176000000  btcusd  18364.000000  19131.000000  19400.00000  18130.00000
# 1606262400000  btcusd  19133.654712  18727.000000  19497.00000  18500.00000
# 1606348800000  btcusd  18726.475677  17211.695801  18908.00000  16317.00000
# 1606435200000  btcusd  17213.000000  17171.000000  17531.00000  16501.00000
# 1606521600000  btcusd  17171.000000  17686.840768  17705.00000  16925.00000
#
# [2793 rows x 5 columns]

# %% [markdown]
# Rows can be dropped with axis=0, which is the default:

# %%
# drops the first row which has this value for 'time'
btc_df.drop(1364688000000)
# Out:
#                symbol          open         close        high          low  \
# time
# 1364774400000  btcusd     93.250000    103.999000    105.9000     92.49999
# 1364860800000  btcusd    104.000000    118.229354    118.3867     99.00000
# 1364947200000  btcusd    117.958261    134.700000    146.8800    101.51088
# 1365033600000  btcusd    134.716560    132.899000    143.0000    119.00000
# 1365120000000  btcusd    130.100010    142.300000    145.0000    128.25000
# ...               ...           ...           ...         ...          ...
# 1606176000000  btcusd  18364.000000  19131.000000  19400.0000  18130.00000
# 1606262400000  btcusd  19133.654712  18727.000000  19497.0000  18500.00000
# 1606348800000  btcusd  18726.475677  17211.695801  18908.0000  16317.00000
# 1606435200000  btcusd  17213.000000  17171.000000  17531.0000  16501.00000
# 1606521600000  btcusd  17171.000000  17686.840768  17705.0000  16925.00000
#
#                      volume
# time
# 1364774400000   5224.401313
# 1364860800000   8376.527478
# 1364947200000  12996.245072
# 1365033600000   6981.668305
# 1365120000000   5234.882203
# ...                     ...
# 1606176000000  14937.354569
# 1606262400000  13477.604832
# 1606348800000  34343.561464
# 1606435200000  11217.912098
# 1606521600000   3535.952749
#
# [2792 rows x 6 columns]

# %% [markdown]
# These drop and other transformation methods often have an 'inplace' argument which does not return a new dataframe, but modifies the existing one in-place.

# %%
btc_df.drop('volume', axis=1, inplace=True)

# %% [markdown]
# It can also be helpful to drop missing values. The easiest way is with dropna:

# %%
df = pd.DataFrame(data={'City': ['Los Angeles', 'San Francisco', 'New York', 'Omaha', 'Atlantis'],
                        'State': ['CA', 'CA', 'NY', 'NE', pd.NA]})

df.dropna()
# Out:
#             City State
# 0    Los Angeles    CA
# 1  San Francisco    CA
# 2       New York    NY
# 3          Omaha    NE

# %%
df.dropna(subset=['State'])
# Out:
#             City State
# 0    Los Angeles    CA
# 1  San Francisco    CA
# 2       New York    NY
# 3          Omaha    NE

# %% [markdown]
# ## Filling missing values

# %%
df.fillna({'City': df['City'].mode()[0], 'State': df['State'].mode()[0]})
# Out:
#             City State
# 0    Los Angeles    CA
# 1  San Francisco    CA
# 2       New York    NY
# 3          Omaha    NE
# 4       Atlantis    CA

# %%
df.City.mode()
# Out:
# 0         Atlantis
# 1      Los Angeles
# 2         New York
# 3            Omaha
# 4    San Francisco
# dtype: object

# %%
df.State.mode()[0]
# Out:
# 'CA'

# %% [markdown]
# ## Detecting outliers

# %% [markdown]
# ## swifter

# %% [markdown]
# # Using Essential pandas Data Wrangling Tools
#
# ## apply

# %% [markdown]
# ## group by

# %% [markdown]
# ## reduce and map

# %% [markdown]
# ## datetimes and timezones

# %% [markdown]
# ## Iterating through dataframes

# %% [markdown]
# # Understanding NumPy Basics
#
# arrays
# converting lists to arrays
#
# matrices
#
# shapes
#
# dtypes
#
# getting numpy from pandas
#
# concatenating arrays

# %% [markdown]
# # Using NumPy Mathematical Functions
#
# multiplication, addition
#
# array addition
#
# log
#
# sin
#
# euclidean distance, cosine distance
