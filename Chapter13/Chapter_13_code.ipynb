# %%
import pandas as pd

df = pd.read_excel('../Chapter11/data/default of credit card clients.xls', skiprows=1, index_col=0)

# %% [markdown]
# # AutoML

# %%
features = df.drop('default payment next month', axis=1)
targets = df['default payment next month']

# %%
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# %% [markdown]
# How is pycaret dealing with categorical values? OHE?
# How is it dealing with scaling? at all?
# Problem with AUC calculation? Some are 0 while accuracy is similar.

# %%
from pycaret.classification import setup, compare_models, models

scaled_df = pd.DataFrame(data=scaled_features)
scaled_df['default payment next month'] = df['default payment next month']

exp_clf = setup(scaled_df, target='default payment next month')
best = compare_models()
# Out:
# <style  type="text/css" >
#     #T_3b8002cb_8f76_11eb_a981_b0359fc83c86 th {
#           text-align: left;
# ...

# %%
exp_clf = setup(df, target='default payment next month')
best = compare_models()
# Out:
# <style  type="text/css" >
#     #T_026445ce_8f74_11eb_999f_b0359fc83c86 th {
#           text-align: left;
# ...

# %%
best.

# %%
models()
